# %%
from matplotlib import rcParams
rcParams['font.family'] = 'Arial'

import matplotlib.pyplot as plt
import numpy as np
t_conj_wtm1,cv1_conj_wtm1,cv2_conj_wtm1,sigma_cv1_conj_wtm1,sigma_cv2_conj_wtm1,hills_height_conj_wtm1,bias_factor_conj_wtm1 = np.loadtxt("../1LYZ_conj_water_wtm_9/md_wtm_1_sprenger/HILLS_mod", comments=["@","#"], unpack=True)
t_conj_wtm2,cv1_conj_wtm2,cv2_conj_wtm2,sigma_cv1_conj_wtm2,sigma_cv2_conj_wtm2,hills_height_conj_wtm2,bias_factor_conj_wtm2 = np.loadtxt("../1LYZ_conj_water_wtm_9/md_wtm_2_sprenger_new/HILLS_mod", comments=["@","#"], unpack=True)
t_conj_wtm3,cv1_conj_wtm3,cv2_conj_wtm3,sigma_cv1_conj_wtm3,sigma_cv2_conj_wtm3,hills_height_conj_wtm3,bias_factor_conj_wtm3 = np.loadtxt("../1LYZ_conj_water_wtm_9/md_wtm_3_sprenger_new_2/HILLS_mod", comments=["@","#"], unpack=True)

t_conj2_wtm1,cv1_conj2_wtm1,cv2_conj2_wtm1,sigma_cv1_conj2_wtm1,sigma_cv2_conj2_wtm1,hills_height_conj2_wtm1,bias_factor_conj2_wtm1 = np.loadtxt("../1LYZ_conj2_water_wtm_9/md_wtm_1_sprenger_new_2/HILLS_mod", comments=["@","#"], unpack=True)
t_conj2_wtm2,cv1_conj2_wtm2,cv2_conj2_wtm2,sigma_cv1_conj2_wtm2,sigma_cv2_conj2_wtm2,hills_height_conj2_wtm2,bias_factor_conj2_wtm2 = np.loadtxt("../1LYZ_conj2_water_wtm_9/md_wtm_2_sprenger_new/HILLS_mod", comments=["@","#"], unpack=True)
t_conj2_wtm3,cv1_conj2_wtm3,cv2_conj2_wtm3,sigma_cv1_conj2_wtm3,sigma_cv2_conj2_wtm3,hills_height_conj2_wtm3,bias_factor_conj2_wtm3 = np.loadtxt("../1LYZ_conj2_water_wtm_9/md_wtm_3_sprenger_new/HILLS_mod", comments=["@","#"], unpack=True)

t_conj_wtm1 = t_conj_wtm1/1000
t_conj_wtm2 = t_conj_wtm2/1000
t_conj_wtm3 = t_conj_wtm3/1000
t_conj2_wtm1 = t_conj2_wtm1/1000
t_conj2_wtm2 = t_conj2_wtm2/1000
t_conj2_wtm3 = t_conj2_wtm3/1000

plt.figure(figsize = (15, 6))
plt.plot(t_conj_wtm1, hills_height_conj_wtm1, color = "darkorange", label = "1LYZ-3(mPEG4) WTM 1", linewidth = 1,alpha=1)
plt.plot(t_conj_wtm2, hills_height_conj_wtm2, color = "forestgreen", label = "1LYZ-3(mPEG4) WTM 2", linewidth = 1,alpha=0.9)
plt.plot(t_conj_wtm3, hills_height_conj_wtm3, color = "darkviolet", label = "1LYZ-3(mPEG4) WTM 3", linewidth = 1,alpha=0.8)
#plt.xlim(0,1000)
plt.xticks(ticks=[0,100,200,300,400,500,600,700,800,900,1000],fontsize=18)
plt.yticks(ticks=[0,0.5,1.0,1.5,2.0],fontsize=18)
#plt.ylim(0,2)
plt.xlabel('Time (ns)', fontsize = 20)
plt.ylabel('Hills Height (kJ/mol)', fontsize = 20)
plt.title('WTM Hills Height', fontsize = 20)
plt.legend(fontsize = 16, frameon = False)
plt.savefig("wtm9_hills_height_conj_ms.svg",bbox_inches='tight')
plt.savefig("wtm9_hills_height_conj_trans_ms.svg",bbox_inches='tight',transparent=True)
plt.show()

plt.figure(figsize = (15, 6))
plt.plot(t_conj2_wtm1, hills_height_conj2_wtm1, color = "darkorange", label = "1LYZ-3(mPEG8) WTM 1", linewidth = 1,alpha=1)
plt.plot(t_conj2_wtm2, hills_height_conj2_wtm2, color = "forestgreen", label = "1LYZ-3(mPEG8) WTM 2", linewidth = 1,alpha=0.9)
plt.plot(t_conj2_wtm3, hills_height_conj2_wtm3, color = "darkviolet", label = "1LYZ-3(mPEG8) WTM 3", linewidth = 1,alpha=0.8)
#plt.xlim(0,1000)
plt.xticks(ticks=[0,100,200,300,400,500,600,700,800,900,1000],fontsize=18)
plt.yticks(ticks=[0,0.5,1.0,1.5,2.0],fontsize=18)
#plt.ylim(0,2)
plt.xlabel('Time (ns)', fontsize = 20)
plt.ylabel('Hills Height (kJ/mol)', fontsize = 20)
plt.title('WTM Hills Height', fontsize = 20)
plt.legend(fontsize = 16, frameon = False)
plt.savefig("wtm9_hills_height_conj2_ms.svg",bbox_inches='tight')
plt.savefig("wtm9_hills_height_conj2_trans_ms.svg",bbox_inches='tight',transparent=True)
plt.show()
