# %%
import numpy as np
from matplotlib import rcParams
rcParams['font.family'] = 'Arial'
import matplotlib.pyplot as plt
import numpy as np

t_ab_com_bilayer_phosphate_p_1_unbiased, dist_ab_com_bilayer_phosphate_p_x_1_unbiased, dist_ab_com_bilayer_phosphate_p_y_1_unbiased, dist_ab_com_bilayer_phosphate_p_z_1_unbiased = np.loadtxt("../DOPC100-120x120x180_box-1x_5OQV_new_2/md_npt/ortho_dist_ab_com_bilayer_top_phosphate_p_com.colvar", comments=["@","#"], unpack=True)
t_ab_com_bilayer_phosphate_p_2_unbiased, dist_ab_com_bilayer_phosphate_p_x_2_unbiased, dist_ab_com_bilayer_phosphate_p_y_2_unbiased, dist_ab_com_bilayer_phosphate_p_z_2_unbiased = np.loadtxt("../DOPG100-120x120x180_box-1x_5OQV_new/md_npt/ortho_dist_ab_com_bilayer_top_phosphate_p_com.colvar", comments=["@","#"], unpack=True)
#t_ab_com_bilayer_phosphate_p_3_unbiased, dist_ab_com_bilayer_phosphate_p_x_3_unbiased, dist_ab_com_bilayer_phosphate_p_y_3_unbiased, dist_ab_com_bilayer_phosphate_p_z_3_unbiased = np.loadtxt("../DOPG75-DOPC25-120x120x180_box-1x_5OQV_new/md_npt/ortho_dist_ab_com_bilayer_top_phosphate_p_com.colvar", comments=["@","#"], unpack=True)
t_ab_com_bilayer_phosphate_p_4_unbiased, dist_ab_com_bilayer_phosphate_p_x_4_unbiased, dist_ab_com_bilayer_phosphate_p_y_4_unbiased, dist_ab_com_bilayer_phosphate_p_z_4_unbiased = np.loadtxt("../DOPG50-DOPC50-120x120x180_box-1x_5OQV_new/md_npt/ortho_dist_ab_com_bilayer_top_phosphate_p_com.colvar", comments=["@","#"], unpack=True)
#t_ab_com_bilayer_phosphate_p_5_unbiased, dist_ab_com_bilayer_phosphate_p_x_5_unbiased, dist_ab_com_bilayer_phosphate_p_y_5_unbiased, dist_ab_com_bilayer_phosphate_p_z_5_unbiased = np.loadtxt("../DOPG25-DOPC75-120x120x180_box-1x_5OQV_new/md_npt/ortho_dist_ab_com_bilayer_top_phosphate_p_com.colvar", comments=["@","#"], unpack=True)
t_ab_com_bilayer_phosphate_p_1_wtm, dist_ab_com_bilayer_phosphate_p_x_1_wtm, dist_ab_com_bilayer_phosphate_p_y_1_wtm, dist_ab_com_bilayer_phosphate_p_z_1_wtm = np.loadtxt("../DOPC100-120x120x180_box-1x_5OQV_new/md_wtm/wtm_npt_alpine_6/ortho_dist_ab_com_bilayer_top_phosphate_p_com.colvar", comments=["@","#"], unpack=True)
t_ab_com_bilayer_phosphate_p_2_wtm, dist_ab_com_bilayer_phosphate_p_x_2_wtm, dist_ab_com_bilayer_phosphate_p_y_2_wtm, dist_ab_com_bilayer_phosphate_p_z_2_wtm = np.loadtxt("../DOPG100-120x120x180_box-1x_5OQV_new/md_wtm/wtm_npt_alpine_6/ortho_dist_ab_com_bilayer_top_phosphate_p_com.colvar", comments=["@","#"], unpack=True)
#t_ab_com_bilayer_phosphate_p_3_wtm, dist_ab_com_bilayer_phosphate_p_x_3_wtm, dist_ab_com_bilayer_phosphate_p_y_3_wtm, dist_ab_com_bilayer_phosphate_p_z_3_wtm = np.loadtxt("../DOPG75-DOPC25-120x120x180_box-1x_5OQV_new/md_wtm/wtm_npt_alpine_6/ortho_dist_ab_com_bilayer_top_phosphate_p_com.colvar", comments=["@","#"], unpack=True)
t_ab_com_bilayer_phosphate_p_4_wtm, dist_ab_com_bilayer_phosphate_p_x_4_wtm, dist_ab_com_bilayer_phosphate_p_y_4_wtm, dist_ab_com_bilayer_phosphate_p_z_4_wtm = np.loadtxt("../DOPG50-DOPC50-120x120x180_box-1x_5OQV_new/md_wtm/wtm_npt_alpine_6/ortho_dist_ab_com_bilayer_top_phosphate_p_com.colvar", comments=["@","#"], unpack=True)
#t_ab_com_bilayer_phosphate_p_5_wtm, dist_ab_com_bilayer_phosphate_p_x_5_wtm, dist_ab_com_bilayer_phosphate_p_y_5_wtm, dist_ab_com_bilayer_phosphate_p_z_5_wtm = np.loadtxt("../DOPG25-DOPC75-120x120x180_box-1x_5OQV_new/md_wtm/wtm_npt_alpine_6/ortho_dist_ab_com_bilayer_top_phosphate_p_com.colvar", comments=["@","#"], unpack=True)

dist_ab_com_bilayer_phosphate_p_z_1_wtm = [i + 18 if i < 0 else i for i in dist_ab_com_bilayer_phosphate_p_z_1_wtm]

t_ab_com_bilayer_phosphate_p_1_unbiased = t_ab_com_bilayer_phosphate_p_1_unbiased/1000
t_ab_com_bilayer_phosphate_p_2_unbiased = t_ab_com_bilayer_phosphate_p_2_unbiased/1000
#t_ab_com_bilayer_phosphate_p_3_unbiased = t_ab_com_bilayer_phosphate_p_3_unbiased/1000
t_ab_com_bilayer_phosphate_p_4_unbiased = t_ab_com_bilayer_phosphate_p_4_unbiased/1000
#t_ab_com_bilayer_phosphate_p_5_unbiased = t_ab_com_bilayer_phosphate_p_5_unbiased/1000
t_ab_com_bilayer_phosphate_p_1_wtm = t_ab_com_bilayer_phosphate_p_1_wtm/1000
t_ab_com_bilayer_phosphate_p_2_wtm = t_ab_com_bilayer_phosphate_p_2_wtm/1000
#t_ab_com_bilayer_phosphate_p_3_wtm = t_ab_com_bilayer_phosphate_p_3_wtm/1000
t_ab_com_bilayer_phosphate_p_4_wtm = t_ab_com_bilayer_phosphate_p_4_wtm/1000
#t_ab_com_bilayer_phosphate_p_5__wtm = t_ab_com_bilayer_phosphate_p_5_wtm/1000

plt.show()
plt.figure(figsize = (15, 5))
plt.plot(t_ab_com_bilayer_phosphate_p_1_unbiased, dist_ab_com_bilayer_phosphate_p_z_1_unbiased, label = "AB-Bilayer Orthoganal Distance (DOPC100 5OQV Fibril Unbiased)", color = 'black', alpha=1, linewidth=1.2)
plt.plot(t_ab_com_bilayer_phosphate_p_1_wtm, dist_ab_com_bilayer_phosphate_p_z_1_wtm, label = "AB-Bilayer Orthoganal Distance (DOPC100 5OQV Fibril WTM)", color = 'red', alpha=0.90, linewidth=1.2)
plt.legend(loc = 'best', fontsize=14, frameon=False)
plt.xlim([0,1000])
plt.xticks([0,100,200,300,400,500,600,700,800,900,1000], fontsize=16)
#plt.ylim([0,14])
#plt.yticks([0,2,4,6,8,10,12,14], fontsize=16)
plt.xlabel('Time (ns)', fontsize=18)
plt.ylabel('Orthogonal Distance (nm)', fontsize=18)
plt.title('AB-Bilayer Orthoganal Distance', fontsize=18, fontweight ="bold")
plt.savefig("wtm_unbiased_comparison_dopc100_5oqv_od_new.svg", bbox_inches='tight')
plt.savefig("wtm_unbiased_comparison_dopc100_5oqv_od_trans_new.svg", bbox_inches='tight',transparent=True)
plt.show()
"""
plt.show()
plt.figure(figsize = (15, 5))
plt.plot(t_ab_com_bilayer_phosphate_p_3_unbiased, dist_ab_com_bilayer_phosphate_p_z_3_unbiased, label = "AB-Bilayer Orthoganal Distance (DOPG25-DOPC75 5OQV Fibril Unbiased)", color = 'black', alpha=1, linewidth=1.2)
plt.plot(t_ab_com_bilayer_phosphate_p_3_wtm, dist_ab_com_bilayer_phosphate_p_z_3_wtm, label = "AB-Bilayer Orthoganal Distance (DOPG25-DOPC75 5OQV Fibril WTM)", color = 'red', alpha=0.90, linewidth=1.2)
plt.legend(loc = 'best', fontsize=14, frameon=False)
plt.xlim([0,1000])
plt.xticks([0,100,200,300,400,500,600,700,800,900,1000], fontsize=16)
#plt.ylim([0,14])
#plt.yticks([0,2,4,6,8,10,12,14], fontsize=16)
plt.xlabel('Time (ns)', fontsize=18)
plt.ylabel('Orthogonal Distance (nm)', fontsize=18)
plt.title('AB-Bilayer Orthoganal Distance', fontsize=18, fontweight ="bold")
plt.savefig("wtm_unbiased_comparison_dopg25-dopc75_5oqv_od_new.svg", bbox_inches='tight')
plt.savefig("wtm_unbiased_comparison_dopg25-dopc75_5oqv_od_trans_new.svg", bbox_inches='tight',transparent=True)
plt.show()
"""
plt.show()
plt.figure(figsize = (15, 5))
plt.plot(t_ab_com_bilayer_phosphate_p_4_unbiased, dist_ab_com_bilayer_phosphate_p_z_4_unbiased, label = "AB-Bilayer Orthoganal Distance (DOPG50-DOPC50 5OQV Fibril Unbiased)", color = 'black', alpha=1, linewidth=1.2)
plt.plot(t_ab_com_bilayer_phosphate_p_4_wtm, dist_ab_com_bilayer_phosphate_p_z_4_wtm, label = "AB-Bilayer Orthoganal Distance (DOPG50-DOPC50 5OQV Fibril WTM)", color = 'red', alpha=0.90, linewidth=1.2)
plt.legend(loc = 'best', fontsize=14, frameon=False)
plt.xlim([0,1000])
plt.xticks([0,100,200,300,400,500,600,700,800,900,1000], fontsize=16)
#plt.ylim([0,14])
#plt.yticks([0,2,4,6,8,10,12,14], fontsize=16)
plt.xlabel('Time (ns)', fontsize=18)
plt.ylabel('Orthogonal Distance (nm)', fontsize=18)
plt.title('AB-Bilayer Orthoganal Distance', fontsize=18, fontweight ="bold")
plt.savefig("wtm_unbiased_comparison_dopg50-dopc50_5oqv_od_new.svg", bbox_inches='tight')
plt.savefig("wtm_unbiased_comparison_dopg50-dopc50_5oqv_od_trans_new.svg", bbox_inches='tight',transparent=True)
plt.show()
"""
plt.show()
plt.figure(figsize = (15, 5))
plt.plot(t_ab_com_bilayer_phosphate_p_5_unbiased, dist_ab_com_bilayer_phosphate_p_z_5_unbiased, label = "AB-Bilayer Orthoganal Distance (DOPG75-DOPC25 5OQV Fibril Unbiased)", color = 'black', alpha=1, linewidth=1.2)
plt.plot(t_ab_com_bilayer_phosphate_p_5_wtm, dist_ab_com_bilayer_phosphate_p_z_5_wtm, label = "AB-Bilayer Orthoganal Distance (DOPG75-DOPC25 5OQV Fibril WTM)", color = 'red', alpha=0.90, linewidth=1.2)
plt.legend(loc = 'best', fontsize=14, frameon=False)
plt.xlim([0,1000])
plt.xticks([0,100,200,300,400,500,600,700,800,900,1000], fontsize=16)
#plt.ylim([0,14])
#plt.yticks([0,2,4,6,8,10,12,14], fontsize=16)
plt.xlabel('Time (ns)', fontsize=18)
plt.ylabel('Orthogonal Distance (nm)', fontsize=18)
plt.title('AB-Bilayer Orthoganal Distance', fontsize=18, fontweight ="bold")
plt.savefig("wtm_unbiased_comparison_dopg75-dopc25_5oqv_od_new.svg", bbox_inches='tight')
plt.savefig("wtm_unbiased_comparison_dopg75-dopc25_5oqv_od_trans_new.svg", bbox_inches='tight',transparent=True)
plt.show()
"""
plt.show()
plt.figure(figsize = (15, 5))
plt.plot(t_ab_com_bilayer_phosphate_p_2_unbiased, dist_ab_com_bilayer_phosphate_p_z_2_unbiased, label = "AB-Bilayer Orthoganal Distance (DOPG100 5OQV Fibril Unbiased)", color = 'black', alpha=1, linewidth=1.2)
plt.plot(t_ab_com_bilayer_phosphate_p_2_wtm, dist_ab_com_bilayer_phosphate_p_z_2_wtm, label = "AB-Bilayer Orthoganal Distance (DOPG100 5OQV Fibril WTM)", color = 'red', alpha=0.90, linewidth=1.2)
plt.legend(loc = 'best', fontsize=14, frameon=False)
plt.xlim([0,1000])
plt.xticks([0,100,200,300,400,500,600,700,800,900,1000], fontsize=16)
#plt.ylim([0,14])
#plt.yticks([0,2,4,6,8,10,12,14], fontsize=16)
plt.xlabel('Time (ns)', fontsize=18)
plt.ylabel('Orthogonal Distance (nm)', fontsize=18)
plt.title('AB-Bilayer Orthoganal Distance', fontsize=18, fontweight ="bold")
plt.savefig("wtm_unbiased_comparison_dopg100_5oqv_od_new.svg", bbox_inches='tight')
plt.savefig("wtm_unbiased_comparison_dopg100_5oqv_od_trans_new.svg", bbox_inches='tight',transparent=True)
plt.show()

# %%
import numpy as np
from matplotlib import rcParams
rcParams['font.family'] = 'Arial'
import matplotlib.pyplot as plt
import numpy as np

t_ab_position_z_1_unbiased, position_ab_z_1_unbiased = np.loadtxt("../DOPC100-120x120x180_box-1x_5OQV_new_2/md_npt/positon_ab_com.colvar", comments=["@","#"], unpack=True)
t_ab_position_z_2_unbiased, position_ab_z_2_unbiased = np.loadtxt("../DOPG100-120x120x180_box-1x_5OQV_new/md_npt/positon_ab_com.colvar", comments=["@","#"], unpack=True)
#t_ab_position_z_3_unbiased, position_ab_z_3_unbiased = np.loadtxt("../DOPG75-DOPC25-120x120x180_box-1x_5OQV_new/md_npt/positon_ab_com.colvar", comments=["@","#"], unpack=True)
t_ab_position_z_4_unbiased, position_ab_z_4_unbiased = np.loadtxt("../DOPG50-DOPC50-120x120x180_box-1x_5OQV_new/md_npt/positon_ab_com.colvar", comments=["@","#"], unpack=True)
#t_ab_position_z_5_unbiased, position_ab_z_5_unbiased = np.loadtxt("../DOPG25-DOPC75-120x120x180_box-1x_5OQV_new/md_npt/positon_ab_com.colvar", comments=["@","#"], unpack=True)
t_ab_position_z_1_wtm, position_ab_z_1_wtm = np.loadtxt("../DOPC100-120x120x180_box-1x_5OQV_new/md_wtm/wtm_npt_alpine_6/positon_ab_com.colvar", comments=["@","#"], unpack=True)
t_ab_position_z_2_wtm, position_ab_z_2_wtm = np.loadtxt("../DOPG100-120x120x180_box-1x_5OQV_new/md_wtm/wtm_npt_alpine_6/positon_ab_com.colvar", comments=["@","#"], unpack=True)
#t_ab_position_z_3_wtm, position_ab_z_3_wtm = np.loadtxt("../DOPG75-DOPC25-120x120x180_box-1x_5OQV_new/md_wtm/wtm_npt_alpine_6/positon_ab_com.colvar", comments=["@","#"], unpack=True)
t_ab_position_z_4_wtm, position_ab_z_4_wtm = np.loadtxt("../DOPG50-DOPC50-120x120x180_box-1x_5OQV_new/md_wtm/wtm_npt_alpine_6/positon_ab_com.colvar", comments=["@","#"], unpack=True)
#t_ab_position_z_5_wtm, position_ab_z_5_wtm = np.loadtxt("../DOPG25-DOPC75-120x120x180_box-1x_5OQV_new/md_wtm/wtm_npt_alpine_6/positon_ab_com.colvar", comments=["@","#"], unpack=True)

position_ab_z_1_wtm = [i + 18 if i < 2 else i for i in position_ab_z_1_wtm]

t_ab_position_z_1_unbiased = t_ab_position_z_1_unbiased/1000
t_ab_position_z_2_unbiased = t_ab_position_z_2_unbiased/1000
#t_ab_position_z_3_unbiased = t_ab_position_z_3_unbiased/1000
t_ab_position_z_4_unbiased = t_ab_position_z_4_unbiased/1000
#t_ab_position_z_5_unbiased = t_ab_position_z_5_unbiased/1000
t_ab_position_z_1_wtm = t_ab_position_z_1_wtm/1000
t_ab_position_z_2_wtm = t_ab_position_z_2_wtm/1000
#t_ab_position_z_3_wtm = t_ab_position_z_3_wtm/1000
t_ab_position_z_4_wtm = t_ab_position_z_4_wtm/1000
#t_ab_position_z_5_wtm = t_ab_position_z_5_wtm/1000

plt.show()
plt.figure(figsize = (15, 5))
plt.plot(t_ab_position_z_1_unbiased, position_ab_z_1_unbiased, label = "AB Orthogonal Position (DOPC100 5OQV Fibril Unbiased)", color = 'black', alpha=1, linewidth=1.2)
plt.plot(t_ab_position_z_1_wtm, position_ab_z_1_wtm, label = "AB Orthogonal Position (DOPC100 5OQV Fibril WTM)", color = 'red', alpha=0.90, linewidth=1.2)
plt.legend(loc = 'best', fontsize=14, frameon=False)
plt.xlim([0,1000])
plt.xticks([0,100,200,300,400,500,600,700,800,900,1000], fontsize=16)
#plt.ylim([0,14])
#plt.yticks([0,2,4,6,8,10,12,14], fontsize=16)
plt.xlabel('Time (ns)', fontsize=18)
plt.ylabel('Position (nm)', fontsize=18)
plt.title('AB Orthoganal Position', fontsize=18, fontweight ="bold")
plt.savefig("wtm_unbiased_comparison_dopc100_5oqv_position_new.svg", bbox_inches='tight')
plt.savefig("wtm_unbiased_comparison_dopc100_5oqv_position_trans_new.svg", bbox_inches='tight',transparent=True)
plt.show()
"""
plt.show()
plt.figure(figsize = (15, 5))
plt.plot(t_ab_position_z_3_unbiased, position_ab_z_3_unbiased, label = "AB Orthogonal Position (DOPG25-DOPC75 5OQV Fibril Unbiased)", color = 'black', alpha=1, linewidth=1.2)
plt.plot(t_ab_position_z_3_wtm, position_ab_z_3_wtm, label = "AB Orthogonal Position (DOPG25-DOPC75 5OQV Fibril WTM)", color = 'red', alpha=0.90, linewidth=1.2)
plt.legend(loc = 'best', fontsize=14, frameon=False)
plt.xlim([0,1000])
plt.xticks([0,100,200,300,400,500,600,700,800,900,1000], fontsize=16)
#plt.ylim([0,14])
#plt.yticks([0,2,4,6,8,10,12,14], fontsize=16)
plt.xlabel('Time (ns)', fontsize=18)
plt.ylabel('Position (nm)', fontsize=18)
plt.title('AB Orthoganal Position', fontsize=18, fontweight ="bold")
plt.savefig("wtm_unbiased_comparison_dopg25-dopc75_5oqv_position_new.svg", bbox_inches='tight')
plt.savefig("wtm_unbiased_comparison_dopg25-dopc75_5oqv_position_trans_new.svg", bbox_inches='tight',transparent=True)
plt.show()
"""
plt.show()
plt.figure(figsize = (15, 5))
plt.plot(t_ab_position_z_4_unbiased, position_ab_z_4_unbiased, label = "AB Orthogonal Position (DOPG50-DOPC50 5OQV Fibril Unbiased)", color = 'black', alpha=1, linewidth=1.2)
plt.plot(t_ab_position_z_4_wtm, position_ab_z_4_wtm, label = "AB Orthogonal Position (DOPG50-DOPC50 5OQV Fibril WTM)", color = 'red', alpha=0.90, linewidth=1.2)
plt.legend(loc = 'best', fontsize=14, frameon=False)
plt.xlim([0,1000])
plt.xticks([0,100,200,300,400,500,600,700,800,900,1000], fontsize=16)
#plt.ylim([0,14])
#plt.yticks([0,2,4,6,8,10,12,14], fontsize=16)
plt.xlabel('Time (ns)', fontsize=18)
plt.ylabel('Position (nm)', fontsize=18)
plt.title('AB Orthoganal Position', fontsize=18, fontweight ="bold")
plt.savefig("wtm_unbiased_comparison_dopg50-dopc50_5oqv_position_new.svg", bbox_inches='tight')
plt.savefig("wtm_unbiased_comparison_dopg50-dopc50_5oqv_position_trans_new.svg", bbox_inches='tight',transparent=True)
plt.show()
"""
plt.show()
plt.figure(figsize = (15, 5))
plt.plot(t_ab_position_z_5_unbiased, position_ab_z_5_unbiased, label = "AB Orthogonal Position (DOPG75-DOPC25 5OQV Fibril Unbiased)", color = 'black', alpha=1, linewidth=1.2)
plt.plot(t_ab_position_z_5_wtm, position_ab_z_5_wtm, label = "AB Orthogonal Position (DOPG75-DOPC25 5OQV Fibril WTM)", color = 'red', alpha=0.90, linewidth=1.2)
plt.legend(loc = 'best', fontsize=14, frameon=False)
plt.xlim([0,1000])
plt.xticks([0,100,200,300,400,500,600,700,800,900,1000], fontsize=16)
#plt.ylim([0,14])
#plt.yticks([0,2,4,6,8,10,12,14], fontsize=16)
plt.xlabel('Time (ns)', fontsize=18)
plt.ylabel('Position (nm)', fontsize=18)
plt.title('AB Orthoganal Position', fontsize=18, fontweight ="bold")
plt.savefig("wtm_unbiased_comparison_dopg75-dopc25_5oqv_position_new.svg", bbox_inches='tight')
plt.savefig("wtm_unbiased_comparison_dopg75-dopc25_5oqv_position_trans_new.svg", bbox_inches='tight',transparent=True)
plt.show()
"""
plt.show()
plt.figure(figsize = (15, 5))
plt.plot(t_ab_position_z_2_unbiased, position_ab_z_2_unbiased, label = "AB Orthogonal Position (DOPG100 5OQV Fibril Unbiased)", color = 'black', alpha=1, linewidth=1.2)
plt.plot(t_ab_position_z_2_wtm, position_ab_z_2_wtm, label = "AB Orthogonal Position (DOPG100 5OQV Fibril WTM)", color = 'red', alpha=0.90, linewidth=1.2)
plt.legend(loc = 'best', fontsize=14, frameon=False)
plt.xlim([0,1000])
plt.xticks([0,100,200,300,400,500,600,700,800,900,1000], fontsize=16)
#plt.ylim([0,14])
#plt.yticks([0,2,4,6,8,10,12,14], fontsize=16)
plt.xlabel('Time (ns)', fontsize=18)
plt.ylabel('Position (nm)', fontsize=18)
plt.title('AB Orthoganal Position', fontsize=18, fontweight ="bold")
plt.savefig("wtm_unbiased_comparison_dopg100_5oqv_position_new.svg", bbox_inches='tight')
plt.savefig("wtm_unbiased_comparison_dopg100_5oqv_position_trans_new.svg", bbox_inches='tight',transparent=True)
plt.show()

# %%
import numpy as np
from matplotlib import rcParams
rcParams['font.family'] = 'Arial'
import matplotlib.pyplot as plt
import numpy as np

t_rog_ab_1_unbiased, rog_ab_x_1_unbiased, rog_ab_y_1_unbiased, rog_ab_z_1_unbiased, rog_ab_1_unbiased = np.loadtxt("../DOPC100-120x120x180_box-1x_5OQV_new_2/md_npt/rog_ab.xvg", comments=["@","#"], unpack=True)
t_rog_ab_2_unbiased, rog_ab_x_2_unbiased, rog_ab_y_2_unbiased, rog_ab_z_2_unbiased, rog_ab_2_unbiased = np.loadtxt("../DOPG100-120x120x180_box-1x_5OQV_new/md_npt/rog_ab.xvg", comments=["@","#"], unpack=True)
#t_rog_ab_3_unbiased, rog_ab_x_3_unbiased, rog_ab_y_3_unbiased, rog_ab_z_3_unbiased, rog_ab_3_unbiased = np.loadtxt("../DOPG75-DOPC25-120x120x180_box-1x_5OQV_new/md_npt/rog_ab.xvg", comments=["@","#"], unpack=True)
t_rog_ab_4_unbiased, rog_ab_x_4_unbiased, rog_ab_y_4_unbiased, rog_ab_z_4_unbiased, rog_ab_4_unbiased = np.loadtxt("../DOPG50-DOPC50-120x120x180_box-1x_5OQV_new/md_npt/rog_ab.xvg", comments=["@","#"], unpack=True)
#t_rog_ab_5_unbiased, rog_ab_x_5_unbiased, rog_ab_y_5_unbiased, rog_ab_z_5_unbiased, rog_ab_5_unbiased = np.loadtxt("../DOPG25-DOPC75-120x120x180_box-1x_5OQV_new/md_npt/rog_ab.xvg", comments=["@","#"], unpack=True)
t_rog_ab_1_wtm, rog_ab_x_1_wtm, rog_ab_y_1_wtm, rog_ab_z_1_wtm, rog_ab_1_wtm = np.loadtxt("../DOPC100-120x120x180_box-1x_5OQV_new/md_wtm/wtm_npt_alpine_6/rog_ab.xvg", comments=["@","#"], unpack=True)
t_rog_ab_2_wtm, rog_ab_x_2_wtm, rog_ab_y_2_wtm, rog_ab_z_2_wtm, rog_ab_2_wtm = np.loadtxt("../DOPG100-120x120x180_box-1x_5OQV_new/md_wtm/wtm_npt_alpine_6/rog_ab.xvg", comments=["@","#"], unpack=True)
#t_rog_ab_3_wtm, rog_ab_x_3_wtm, rog_ab_y_3_wtm, rog_ab_z_3_wtm, rog_ab_3_wtm = np.loadtxt("../DOPG75-DOPC25-120x120x180_box-1x_5OQV_new/md_wtm/wtm_npt_alpine_6/rog_ab.xvg", comments=["@","#"], unpack=True)
t_rog_ab_4_wtm, rog_ab_x_4_wtm, rog_ab_y_4_wtm, rog_ab_z_4_wtm, rog_ab_4_wtm = np.loadtxt("../DOPG50-DOPC50-120x120x180_box-1x_5OQV_new/md_wtm/wtm_npt_alpine_6/rog_ab.xvg", comments=["@","#"], unpack=True)
#t_rog_ab_5_wtm, rog_ab_x_5_wtm, rog_ab_y_5_wtm, rog_ab_z_5_wtm, rog_ab_5_wtm = np.loadtxt("../DOPG25-DOPC75-120x120x180_box-1x_5OQV_new/md_wtm/wtm_npt_alpine_6/rog_ab.xvg", comments=["@","#"], unpack=True)

t_rog_ab_1_unbiased = t_rog_ab_1_unbiased/1000
t_rog_ab_2_unbiased = t_rog_ab_2_unbiased/1000
#t_rog_ab_3_unbiased = t_rog_ab_3_unbiased/1000
t_rog_ab_4_unbiased = t_rog_ab_4_unbiased/1000
#t_rog_ab_5_unbiased = t_rog_ab_5_unbiased/1000
t_rog_ab_1_wtm = t_rog_ab_1_wtm/1000
t_rog_ab_2_wtm = t_rog_ab_2_wtm/1000
#t_rog_ab_3_wtm = t_rog_ab_3_wtm/1000
t_rog_ab_4_wtm = t_rog_ab_4_wtm/1000
#t_rog_ab_5__wtm = t_rog_ab_5_wtm/1000

plt.show()
plt.figure(figsize = (15, 5))
plt.plot(t_rog_ab_1_unbiased, rog_ab_1_unbiased, label = "AB Radius of Gyration (DOPC100 5OQV FIbril Unbiased)", color = 'black', alpha=1, linewidth=1.2)
plt.plot(t_rog_ab_1_wtm, rog_ab_1_wtm, label = "AB Radius of Gyration (DOPC100 5OQV FIbril WTM)", color = 'red', alpha=0.90, linewidth=1.2)
plt.legend(loc = 'best', fontsize=14, frameon=False)
plt.xlim([0,1000])
plt.xticks([0,100,200,300,400,500,600,700,800,900,1000], fontsize=16)
#plt.ylim([0,3])
#plt.yticks([0,0.5,1.0,1.5,2.0,2.5,3.0], fontsize=16)
plt.xlabel('Time (ns)', fontsize=18)
plt.ylabel('Radius of Gyration (nm)', fontsize=18)
plt.title('AB Radius of Gyration', fontsize=18, fontweight ="bold")
plt.savefig("wtm_unbiased_comparison_dopc100_5oqv_rog_new.svg", bbox_inches='tight')
plt.savefig("wtm_unbiased_comparison_dopc100_5oqv_rog_trans_new.svg", bbox_inches='tight',transparent=True)
plt.show()
"""
plt.show()
plt.figure(figsize = (15, 5))
plt.plot(t_rog_ab_3_unbiased, rog_ab_3_unbiased, label = "AB Radius of Gyration (DOPG25-DOPC75 5OQV FIbril Unbiased)", color = 'black', alpha=1, linewidth=1.2)
plt.plot(t_rog_ab_3_wtm, rog_ab_3_wtm, label = "AB Radius of Gyration (DOPG25-DOPC75 5OQV FIbril WTM)", color = 'red', alpha=0.90, linewidth=1.2)
plt.legend(loc = 'best', fontsize=14, frameon=False)
plt.xlim([0,1000])
plt.xticks([0,100,200,300,400,500,600,700,800,900,1000], fontsize=16)
#plt.ylim([0,3])
#plt.yticks([0,0.5,1.0,1.5,2.0,2.5,3.0], fontsize=16)
plt.xlabel('Time (ns)', fontsize=18)
plt.ylabel('Radius of Gyration (nm)', fontsize=18)
plt.title('AB Radius of Gyration', fontsize=18, fontweight ="bold")
plt.savefig("wtm_unbiased_comparison_dopg25-dopc75_5oqv_rog_new.svg", bbox_inches='tight')
plt.savefig("wtm_unbiased_comparison_dopg25-dopc75_5oqv_rog_trans_new.svg", bbox_inches='tight',transparent=True)
plt.show()
"""
plt.show()
plt.figure(figsize = (15, 5))
plt.plot(t_rog_ab_4_unbiased, rog_ab_4_unbiased, label = "AB Radius of Gyration (DOPG50-DOPC50 5OQV FIbril Unbiased)", color = 'black', alpha=1, linewidth=1.2)
plt.plot(t_rog_ab_4_wtm, rog_ab_4_wtm, label = "AB Radius of Gyration (DOPG50-DOPC50 5OQV FIbril WTM)", color = 'red', alpha=0.90, linewidth=1.2)
plt.legend(loc = 'best', fontsize=14, frameon=False)
plt.xlim([0,1000])
plt.xticks([0,100,200,300,400,500,600,700,800,900,1000], fontsize=16)
#plt.ylim([0,3])
#plt.yticks([0,0.5,1.0,1.5,2.0,2.5,3.0], fontsize=16)
plt.xlabel('Time (ns)', fontsize=18)
plt.ylabel('Radius of Gyration (nm)', fontsize=18)
plt.title('AB Radius of Gyration', fontsize=18, fontweight ="bold")
plt.savefig("wtm_unbiased_comparison_dopg50-dopc50_5oqv_rog_new.svg", bbox_inches='tight')
plt.savefig("wtm_unbiased_comparison_dopg50-dopc50_5oqv_rog_trans_new.svg", bbox_inches='tight',transparent=True)
plt.show()
"""
plt.show()
plt.figure(figsize = (15, 5))
plt.plot(t_rog_ab_5_unbiased, rog_ab_5_unbiased, label = "AB Radius of Gyration (DOPG75-DOPC25 5OQV FIbril Unbiased)", color = 'black', alpha=1, linewidth=1.2)
plt.plot(t_rog_ab_5_wtm, rog_ab_5_wtm, label = "AB Radius of Gyration (DOPG75-DOPC25 5OQV FIbril WTM)", color = 'red', alpha=0.90, linewidth=1.2)
plt.legend(loc = 'best', fontsize=14, frameon=False)
plt.xlim([0,1000])
plt.xticks([0,100,200,300,400,500,600,700,800,900,1000], fontsize=16)
#plt.ylim([0,3])
#plt.yticks([0,0.5,1.0,1.5,2.0,2.5,3.0], fontsize=16)
plt.xlabel('Time (ns)', fontsize=18)
plt.ylabel('Radius of Gyration (nm)', fontsize=18)
plt.title('AB Radius of Gyration', fontsize=18, fontweight ="bold")
plt.savefig("wtm_unbiased_comparison_dopg75-dopc25_5oqv_rog_new.svg", bbox_inches='tight')
plt.savefig("wtm_unbiased_comparison_dopg75-dopc25_5oqv_rog_trans_new.svg", bbox_inches='tight',transparent=True)
plt.show()
"""
plt.show()
plt.figure(figsize = (15, 5))
plt.plot(t_rog_ab_2_unbiased, rog_ab_2_unbiased, label = "AB Radius of Gyration (DOPG100 5OQV FIbril Unbiased)", color = 'black', alpha=1, linewidth=1.2)
plt.plot(t_rog_ab_2_wtm, rog_ab_2_wtm, label = "AB Radius of Gyration (DOPG100 5OQV FIbril WTM)", color = 'red', alpha=0.90, linewidth=1.2)
plt.legend(loc = 'best', fontsize=14, frameon=False)
plt.xlim([0,1000])
plt.xticks([0,100,200,300,400,500,600,700,800,900,1000], fontsize=16)
#plt.ylim([0,3])
#plt.yticks([0,0.5,1.0,1.5,2.0,2.5,3.0], fontsize=16)
plt.xlabel('Time (ns)', fontsize=18)
plt.ylabel('Radius of Gyration (nm)', fontsize=18)
plt.title('AB Radius of Gyration', fontsize=18, fontweight ="bold")
plt.savefig("wtm_unbiased_comparison_dopg100_5oqv_rog_new.svg", bbox_inches='tight')
plt.savefig("wtm_unbiased_comparison_dopg100_5oqv_rog_trans_new.svg", bbox_inches='tight',transparent=True)
plt.show()
