# %%
import matplotlib.pyplot as plt
import numpy as np
r_sp_pla5, gr_sp_pla5 = np.loadtxt("rdf-surf_surface_polymer_nopbc_new_pla5.xvg", comments=["@","#"], unpack=True)
#r_op_pla5, gr_op_pla5 = np.loadtxt("rdf-surf_oh_polymer_pla5.xvg", comments=["@","#"], unpack=True)
r_ss_pla5, gr_ss_pla5 = np.loadtxt("rdf-surf_surface_solvent_nopbc_new_pla5.xvg", comments=["@","#"], unpack=True)
#r_os_pla5, gr_os_pla5 = np.loadtxt("rdf-surf_oh_solvent_pla5.xvg", comments=["@","#"], unpack=True)
r_sp_pet2, gr_sp_pet2 = np.loadtxt("rdf-surf_surface_polymer_nopbc_new_pet2.xvg", comments=["@","#"], unpack=True)
#r_op_pet2, gr_op_pet2 = np.loadtxt("rdf-surf_oh_polymer_pet2.xvg", comments=["@","#"], unpack=True)
r_ss_pet2, gr_ss_pet2 = np.loadtxt("rdf-surf_surface_solvent_nopbc_new_pet2.xvg", comments=["@","#"], unpack=True)
#r_os_pet2, gr_os_pet2 = np.loadtxt("rdf-surf_oh_solvent_pet2.xvg", comments=["@","#"], unpack=True)
r_sp_pla10, gr_sp_pla10 = np.loadtxt("rdf-surf_surface_polymer_nopbc_new_pla10.xvg", comments=["@","#"], unpack=True)
#r_op_pla10, gr_op_pla10 = np.loadtxt("rdf-surf_oh_polymer_pla10.xvg", comments=["@","#"], unpack=True)
r_ss_pla10, gr_ss_pla10 = np.loadtxt("rdf-surf_surface_solvent_nopbc_new_pla10.xvg", comments=["@","#"], unpack=True)
#r_os_pla10, gr_os_pla10 = np.loadtxt("rdf-surf_oh_solvent_pla10.xvg", comments=["@","#"], unpack=True)
r_sp_pet3, gr_sp_pet3 = np.loadtxt("rdf-surf_surface_polymer_nopbc_new_pet3.xvg", comments=["@","#"], unpack=True)
#r_op_pet3, gr_op_pet3 = np.loadtxt("rdf-surf_oh_polymer_pet2.xvg", comments=["@","#"], unpack=True)
r_ss_pet3, gr_ss_pet3 = np.loadtxt("rdf-surf_surface_solvent_nopbc_new_pet3.xvg", comments=["@","#"], unpack=True)
#r_os_pet3, gr_os_pet3 = np.loadtxt("rdf-surf_oh_solvent_pet3.xvg", comments=["@","#"], unpack=True)

plt.figure(figsize = (15, 10))
plt.subplot(211)
plt.plot(r_sp_pla5, gr_sp_pla5, label = "PLA5")
#plt.plot(r_op_pla5, gr_op_pla5, label = "Reference: MO Surface OH Groups")
plt.plot(r_sp_pet2, gr_sp_pet2, label = "PET2")
#plt.plot(r_op_pet2, gr_op_pet2, label = "Reference: MO Surface OH Groups")
plt.plot(r_sp_pla10, gr_sp_pla10, label = "PLA10")
#plt.plot(r_op_pla10, gr_op_pla10, label = "Reference: MO Surface OH Groups")
plt.plot(r_sp_pet3, gr_sp_pet3, label = "PET3")
#plt.plot(r_op_pet3, gr_op_pet3, label = "Reference: MO Surface OH Groups")
plt.xlim([0,5])
plt.legend(fontsize = 14, loc = 'upper right')
plt.xlabel('Distance (nm)', fontsize = 16)
plt.ylabel('g(r)', fontsize = 16)
plt.title('RDF-Surf of Polymer From Alumina Surface', fontsize = 18)
plt.show()
plt.figure(figsize = (15, 10))
plt.subplot(212)
plt.plot(r_ss_pla5, gr_ss_pla5, label = "PLA5")
#plt.plot(r_os_pla5, gr_os_pla5, label = "Reference: MO Surface OH Groups")
plt.plot(r_ss_pet2, gr_ss_pet2, label = "PET2")
#plt.plot(r_os_pet2, gr_os_pet2, label = "Reference: MO Surface OH Groups")
plt.plot(r_ss_pla10, gr_ss_pla10, label = "PLA10")
#plt.plot(r_os_pla10, gr_os_pla10, label = "Reference: MO Surface OH Groups")
plt.plot(r_ss_pet3, gr_ss_pet3, label = "PET3")
#plt.plot(r_os_pet3, gr_os_pet3, label = "Reference: MO Surface OH Groups")
plt.xlim([0,5])
plt.legend(fontsize = 14, loc = 'upper right')
plt.xlabel('Distance (nm)', fontsize = 16)
plt.ylabel('g(r)', fontsize = 16)
plt.title('RDF-Surf of Solvent From Alumina Surface', fontsize = 18)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
r_spmc_pla5, gr_spmc_pla5 = np.loadtxt("rdf-surf_surface_polymer_methyl_c_nopbc_new_pla5.xvg", comments=["@","#"], unpack=True)
r_spco_pla5, gr_spco_pla5 = np.loadtxt("rdf-surf_surface_polymer_carbonyl_o_nopbc_new_pla5.xvg", comments=["@","#"], unpack=True)
r_speo_pla5, gr_speo_pla5 = np.loadtxt("rdf-surf_surface_polymer_ether_o_nopbc_new_pla5.xvg", comments=["@","#"], unpack=True)
r_sseo_pla5, gr_sseo_pla5 = np.loadtxt("rdf-surf_surface_solvent_ether_o_nopbc_new_pla5.xvg", comments=["@","#"], unpack=True)
r_spac_pet2, gr_spac_pet2 = np.loadtxt("rdf-surf_surface_polymer_aromatic_c_nopbc_new_pet2.xvg", comments=["@","#"], unpack=True)
r_spco_pet2, gr_spco_pet2 = np.loadtxt("rdf-surf_surface_polymer_carbonyl_o_nopbc_new_pet2.xvg", comments=["@","#"], unpack=True)
r_speo_pet2, gr_speo_pet2 = np.loadtxt("rdf-surf_surface_polymer_ether_o_nopbc_new_pet2.xvg", comments=["@","#"], unpack=True)
r_sseo_pet2, gr_sseo_pet2 = np.loadtxt("rdf-surf_surface_solvent_ether_o_nopbc_new_pet2.xvg", comments=["@","#"], unpack=True)
r_spmc_pla10, gr_spmc_pla10 = np.loadtxt("rdf-surf_surface_polymer_methyl_c_nopbc_new_pla10.xvg", comments=["@","#"], unpack=True)
r_spco_pla10, gr_spco_pla10 = np.loadtxt("rdf-surf_surface_polymer_carbonyl_o_nopbc_new_pla10.xvg", comments=["@","#"], unpack=True)
r_speo_pla10, gr_speo_pla10 = np.loadtxt("rdf-surf_surface_polymer_ether_o_nopbc_new_pla10.xvg", comments=["@","#"], unpack=True)
r_sseo_pla10, gr_sseo_pla10 = np.loadtxt("rdf-surf_surface_solvent_ether_o_nopbc_new_pla10.xvg", comments=["@","#"], unpack=True)
r_spac_pet3, gr_spac_pet3 = np.loadtxt("rdf-surf_surface_polymer_aromatic_c_nopbc_new_pet3.xvg", comments=["@","#"], unpack=True)
r_spco_pet3, gr_spco_pet3 = np.loadtxt("rdf-surf_surface_polymer_carbonyl_o_nopbc_new_pet3.xvg", comments=["@","#"], unpack=True)
r_speo_pet3, gr_speo_pet3 = np.loadtxt("rdf-surf_surface_polymer_ether_o_nopbc_new_pet3.xvg", comments=["@","#"], unpack=True)
r_sseo_pet3, gr_sseo_pet3 = np.loadtxt("rdf-surf_surface_solvent_ether_o_nopbc_new_pet3.xvg", comments=["@","#"], unpack=True)

r_ssrc_pla5, gr_ssrc_pla5 = np.loadtxt("rdf-surf_surface_solvent_ring_c_nopbc_new_pla5.xvg", comments=["@","#"], unpack=True)

plt.figure(figsize = (15, 10))
plt.subplot(211)
plt.plot(r_spmc_pla5, gr_spmc_pla5, label = "PLA5 Methyl C")
plt.plot(r_spco_pla5, gr_spco_pla5, label = "PLA5 Carbonyl O")
plt.plot(r_speo_pla5, gr_speo_pla5, label = "PLA5 Ether O")
plt.plot(r_spac_pet2, gr_spac_pet2, label = "PET2 Aromatic C")
plt.plot(r_spco_pet2, gr_spco_pet2, label = "PET2 Carbonyl O")
plt.plot(r_speo_pet2, gr_speo_pet2, label = "PET2 Ether O")
plt.plot(r_spmc_pla10, gr_spmc_pla10, label = "PLA10 Methyl C")
plt.plot(r_spco_pla10, gr_spco_pla10, label = "PLA10 Carbonyl O")
plt.plot(r_speo_pla10, gr_speo_pla10, label = "PLA10 Ether O")
plt.plot(r_spac_pet3, gr_spac_pet3, label = "PET3 Aromatic C")
plt.plot(r_spco_pet3, gr_spco_pet3, label = "PET3 Carbonyl O")
plt.plot(r_speo_pet3, gr_speo_pet3, label = "PET3 Ether O")
plt.xlim([0,5])
plt.legend(fontsize = 14, loc = 'upper right')
plt.xlabel('Distance (nm)', fontsize = 16)
plt.ylabel('g(r)', fontsize = 16)
plt.title('RDF-Surf of Polymer Atom Groups From Alumina Surface', fontsize = 18)
plt.show()
plt.figure(figsize = (15, 10))
plt.subplot(212)
plt.plot(r_sseo_pla5, gr_sseo_pla5, label = "PLA5 System: 14DO Ether O")
plt.plot(r_sseo_pet2, gr_sseo_pet2, label = "PET2 System: 14DO Ether O")
plt.plot(r_sseo_pla10, gr_sseo_pla10, label = "PLA10 System: 14DO Ether O")
plt.plot(r_sseo_pet3, gr_sseo_pet3, label = "PET3 System: 14DO Ether O")
plt.xlim([0,5])
plt.legend(fontsize = 14, loc = 'upper right')
plt.xlabel('Distance (nm)', fontsize = 16)
plt.ylabel('g(r)', fontsize = 16)
plt.title('RDF-Surf of Solvent Atom Groups From Alumina Surface', fontsize = 18)
plt.show()

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'Arial'

from sklearn import preprocessing
import numpy as np

def moving_average(interval,window_size):
    window = np.ones(int(window_size))/float(window_size)
    return np.convolve(interval,window,'same')

gr_sp_arr_pla5 = moving_average(np.array(gr_sp_pla5),10)
gr_ss_arr_pla5 = np.array(gr_ss_pla5)
gr_spmc_arr_pla5 = moving_average(np.array(gr_spmc_pla5),20)
gr_spco_arr_pla5 = moving_average(np.array(gr_spco_pla5),20)
gr_speo_arr_pla5 = moving_average(np.array(gr_speo_pla5),20)
gr_sseo_arr_pla5 = np.array(gr_sseo_pla5)
gr_sp_norm_pla5 = preprocessing.normalize([gr_sp_arr_pla5]).reshape((len(gr_sp_pla5),1))
gr_ss_norm_pla5 = preprocessing.normalize([gr_ss_arr_pla5]).reshape((len(gr_ss_pla5),1))
gr_spmc_norm_pla5 = preprocessing.normalize([gr_spmc_arr_pla5]).reshape((len(gr_spmc_pla5),1))
gr_spco_norm_pla5 = preprocessing.normalize([gr_spco_arr_pla5]).reshape((len(gr_spco_pla5),1))
gr_speo_norm_pla5 = preprocessing.normalize([gr_speo_arr_pla5]).reshape((len(gr_speo_pla5),1))
gr_sseo_norm_pla5 = preprocessing.normalize([gr_sseo_arr_pla5]).reshape((len(gr_sseo_pla5),1))
gr_sp_arr_pet2 = moving_average(np.array(gr_sp_pet2),10)
gr_ss_arr_pet2 = np.array(gr_ss_pet2)
gr_spac_arr_pet2 = moving_average(np.array(gr_spac_pet2),20)
gr_spco_arr_pet2 = moving_average(np.array(gr_spco_pet2),20)
gr_speo_arr_pet2 = moving_average(np.array(gr_speo_pet2),20)
gr_sseo_arr_pet2 = np.array(gr_sseo_pet2)
gr_sp_norm_pet2 = preprocessing.normalize([gr_sp_arr_pet2]).reshape((len(gr_sp_pet2),1))
gr_ss_norm_pet2 = preprocessing.normalize([gr_ss_arr_pet2]).reshape((len(gr_ss_pet2),1))
gr_spac_norm_pet2 = preprocessing.normalize([gr_spac_arr_pet2]).reshape((len(gr_spac_pet2),1))
gr_spco_norm_pet2 = preprocessing.normalize([gr_spco_arr_pet2]).reshape((len(gr_spco_pet2),1))
gr_speo_norm_pet2 = preprocessing.normalize([gr_speo_arr_pet2]).reshape((len(gr_speo_pet2),1))
gr_sseo_norm_pet2 = preprocessing.normalize([gr_sseo_arr_pet2]).reshape((len(gr_sseo_pet2),1))
gr_sp_arr_pla10 = moving_average(np.array(gr_sp_pla10),10)
gr_ss_arr_pla10 = np.array(gr_ss_pla10)
gr_spmc_arr_pla10 = moving_average(np.array(gr_spmc_pla10),20)
gr_spco_arr_pla10 = moving_average(np.array(gr_spco_pla10),20)
gr_speo_arr_pla10 = moving_average(np.array(gr_speo_pla10),20)
gr_sseo_arr_pla10 = np.array(gr_sseo_pla10)
gr_sp_norm_pla10 = preprocessing.normalize([gr_sp_arr_pla10]).reshape((len(gr_sp_pla10),1))
gr_ss_norm_pla10 = preprocessing.normalize([gr_ss_arr_pla10]).reshape((len(gr_ss_pla10),1))
gr_spmc_norm_pla10 = preprocessing.normalize([gr_spmc_arr_pla10]).reshape((len(gr_spmc_pla10),1))
gr_spco_norm_pla10 = preprocessing.normalize([gr_spco_arr_pla10]).reshape((len(gr_spco_pla10),1))
gr_speo_norm_pla10 = preprocessing.normalize([gr_speo_arr_pla10]).reshape((len(gr_speo_pla10),1))
gr_sseo_norm_pla10 = preprocessing.normalize([gr_sseo_arr_pla10]).reshape((len(gr_sseo_pla10),1))
gr_sp_arr_pet3 = moving_average(np.array(gr_sp_pet3),10)
gr_ss_arr_pet3 = np.array(gr_ss_pet3)
gr_spac_arr_pet3 = moving_average(np.array(gr_spac_pet3),20)
gr_spco_arr_pet3 = moving_average(np.array(gr_spco_pet3),20)
gr_speo_arr_pet3 = moving_average(np.array(gr_speo_pet3),20)
gr_sseo_arr_pet3 = np.array(gr_sseo_pet3)
gr_sp_norm_pet3 = preprocessing.normalize([gr_sp_arr_pet3]).reshape((len(gr_sp_pet3),1))
gr_ss_norm_pet3 = preprocessing.normalize([gr_ss_arr_pet3]).reshape((len(gr_ss_pet3),1))
gr_spac_norm_pet3 = preprocessing.normalize([gr_spac_arr_pet3]).reshape((len(gr_spac_pet3),1))
gr_spco_norm_pet3 = preprocessing.normalize([gr_spco_arr_pet3]).reshape((len(gr_spco_pet3),1))
gr_speo_norm_pet3 = preprocessing.normalize([gr_speo_arr_pet3]).reshape((len(gr_speo_pet3),1))
gr_sseo_norm_pet3 = preprocessing.normalize([gr_sseo_arr_pet3]).reshape((len(gr_sseo_pet3),1))

gr_ssrc_arr_pla5 = np.array(gr_ssrc_pla5)
gr_ssrc_norm_pla5 = preprocessing.normalize([gr_ssrc_arr_pla5]).reshape((len(gr_ssrc_pla5),1))

"""
plt.figure(figsize = (15, 5))
plt.plot(r_ss_pla5, gr_ss_norm_pla5, label = "14DO COM", color = "black", linewidth = 3)
plt.plot(r_sseo_pla5, gr_sseo_norm_pla5, label = "14DO Ether O", color = "red", linewidth = 3)
#plt.plot(r_ss_pet2, gr_ss_norm_pet2, label = "PET2 System: 14DO COM")
#plt.plot(r_sseo_pet2, gr_sseo_norm_pet2, label = "PET2 System: 14DO Ether O's")
#plt.plot(r_ss_pla10, gr_ss_norm_pla10, label = "PLA10 COM")
#plt.plot(r_sseo_pla10, gr_sseo_norm_pla10, label = "PLA10 Ether O's")
#plt.plot(r_ss_pet3, gr_ss_norm_pet3, label = "PET2 System: 14DO COM")
#plt.plot(r_sseo_pet3, gr_sseo_norm_pet3, label = "PET2 System: 14DO Ether O's")
plt.vlines(0.270, -0.1, 0.035, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(0.400, -0.1, 0.035, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(0.565, -0.1, 0.035, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(1.010, -0.1, 0.035, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(1.465, -0.1, 0.035, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(1.925, -0.1, 0.035, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(2.370, -0.1, 0.035, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.xlim([0,3])
plt.ylim([-0.001,0.031])
plt.legend(fontsize = 14, loc = 'upper right', frameon = False)
plt.xlabel('Distance (nm)', fontsize = 16)
plt.ylabel('g(r) (Normalized)', fontsize = 16)
plt.title('Mass Distribution of Solvent From Alumina Surface', fontsize = 18)
plt.savefig("rdf-surf_solvent_1.svg",  bbox_inches='tight')
plt.show()
"""
plt.figure(figsize = (15, 5))
plt.plot(r_ss_pla5, gr_ss_pla5, label = "14DO", color = "black", linewidth = 3)
plt.plot(r_sseo_pla5, gr_sseo_pla5, label = "14DO Ether O", color = "red", linewidth = 3)
plt.plot(r_ssrc_pla5, gr_ssrc_pla5, label = "14DO Methylene C", color = "green", linewidth = 3)
##plt.vlines(0.270, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
##plt.vlines(0.400, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(0.570, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(1.010, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(1.465, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(1.925, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(2.370, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(2.825, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(0.205, -1000, 6000, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(0.340, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(0.420, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(0.490, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(0.660, -1000, 6000, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(1.130, -1000, 6000, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(1.595, -1000, 6000, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(2.060, -1000, 6000, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(2.530, -1000, 6000, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(3.000, -1000, 6000, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.xlim([0,4])
plt.xticks(fontsize=18)
plt.ylim([-200,5200])
#plt.ylim([-0.001,0.051])
plt.yticks([0,1000,2000,3000,4000,5000],fontsize=18)
#plt.yticks(fontsize=18)
plt.legend(fontsize = 16, loc = 'upper right', frameon = False)
plt.xlabel('Distance (nm)', fontsize = 20)
plt.ylabel('g(r)', fontsize = 20)
#plt.ylabel('Normalized g(r)', fontsize = 20)
plt.title('Mass Distribution of Solvent From Alumina Surface', fontsize = 20)
plt.savefig("rdf-surf_solvent_2.svg", bbox_inches='tight')
plt.show()

plt.figure(figsize = (15, 5))
plt.plot(r_sp_pla5, gr_sp_arr_pla5, label = "PLA5", color = "red", linewidth = 3)
plt.plot(r_sp_pet2, gr_sp_arr_pet2, label = "PET2", color = "green", linewidth = 3)
plt.plot(r_sp_pla10, gr_sp_arr_pla10, label = "PLA10", color = "orange", linewidth = 3)
plt.plot(r_sp_pet3, gr_sp_arr_pet3, label = "PET3", color = "blue", linewidth = 3)
#plt.plot(r_spmc_pla5, gr_spmc_norm_pla5, label = "PLA5 Methyl C's")
#plt.plot(r_spco_pla5, gr_spco_norm_pla5, label = "PLA5 Carbonyl O's")
#plt.plot(r_speo_pla5, gr_speo_norm_pla5, label = "PLA5 Ether O's")
#plt.plot(r_spac_pet2, gr_spac_norm_pet2, label = "PET2 Aromatic C's")
#plt.plot(r_spco_pet2, gr_spco_norm_pet2, label = "PET2 Carbonyl O's")
#plt.plot(r_speo_pet2, gr_speo_norm_pet2, label = "PET2 Ether O's")
#plt.plot(r_spmc_pla10, gr_spmc_norm_pla10, label = "PLA10 Methyl C's")
#plt.plot(r_spco_pla10, gr_spco_norm_pla10, label = "PLA10 Carbonyl O's")
#plt.plot(r_speo_pla10, gr_speo_norm_pla10, label = "PLA10 Ether O's")
#plt.plot(r_spac_pet3, gr_spac_norm_pet3, label = "PET3 Aromatic C's")
#plt.plot(r_spco_pet3, gr_spco_norm_pet3, label = "PET3 Carbonyl O's")
#plt.plot(r_speo_pet3, gr_speo_norm_pet3, label = "PET3 Ether O's")
plt.xlim([0,4])
plt.xticks(fontsize=18)
plt.ylim([-2,42])
#plt.ylim([-0.002,0.062])
plt.yticks([0,10,20,30,40],fontsize=18)
#plt.yticks(fontsize=18)
plt.legend(fontsize = 16, loc = 'upper right', frameon = False)
plt.xlabel('Distance (nm)', fontsize = 20)
plt.ylabel('g(r)', fontsize = 20)
#plt.ylabel('Normalized g(r)', fontsize = 20)
plt.title('Mass Distribution of Polymer From Alumina Surface', fontsize = 20)
plt.savefig("rdf-surf_polymer.svg", bbox_inches='tight')
plt.show()


plt.figure(figsize = (15, 6))
plt.plot(r_ss_pla5, gr_ss_norm_pla5, label = "14DO COM", color = "black", linewidth = 3)
plt.plot(r_sseo_pla5, gr_sseo_norm_pla5, label = "14DO Ether O", color = "red", linewidth = 3)
plt.plot(r_ssrc_pla5, gr_ssrc_norm_pla5, label = "14DO Methylene C", color = "green", linewidth = 3)
##plt.vlines(0.270, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
##plt.vlines(0.400, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(0.570, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(1.010, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(1.465, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(1.925, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(2.370, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(2.825, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(0.205, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(0.340, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(0.420, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(0.490, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(0.660, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(1.130, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(1.595, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(2.060, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(2.530, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(3.000, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.xlim([0,4])
plt.xticks(fontsize=18)
#plt.ylim([-200,5200])
plt.ylim([-0.001,0.051])
#plt.yticks([0,1000,2000,3000,4000,5000],fontsize=18)
plt.yticks(fontsize=18)
plt.legend(fontsize = 16, loc = 'lower right', frameon = False)
plt.xlabel('Distance (nm)', fontsize = 20)
#plt.ylabel('g(r)', fontsize = 20)
plt.ylabel('          Normalized g(r)', fontsize = 20)
plt.title('Mass Distribution of Solvent From Alumina Surface', fontsize = 20)
plt.savefig("rdf-surf_solvent_2_norm.svg", bbox_inches='tight')
plt.show()

plt.figure(figsize = (15, 6))
plt.plot(r_sp_pla5, gr_sp_norm_pla5, label = "PLA5", color = "red", linewidth = 3)
plt.plot(r_sp_pet2, gr_sp_norm_pet2, label = "PET2", color = "green", linewidth = 3)
plt.plot(r_sp_pla10, gr_sp_norm_pla10, label = "PLA10", color = "orange", linewidth = 3)
plt.plot(r_sp_pet3, gr_sp_norm_pet3, label = "PET3", color = "blue", linewidth = 3)
#plt.plot(r_spmc_pla5, gr_spmc_norm_pla5, label = "PLA5 Methyl C's")
#plt.plot(r_spco_pla5, gr_spco_norm_pla5, label = "PLA5 Carbonyl O's")
#plt.plot(r_speo_pla5, gr_speo_norm_pla5, label = "PLA5 Ether O's")
#plt.plot(r_spac_pet2, gr_spac_norm_pet2, label = "PET2 Aromatic C's")
#plt.plot(r_spco_pet2, gr_spco_norm_pet2, label = "PET2 Carbonyl O's")
#plt.plot(r_speo_pet2, gr_speo_norm_pet2, label = "PET2 Ether O's")
#plt.plot(r_spmc_pla10, gr_spmc_norm_pla10, label = "PLA10 Methyl C's")
#plt.plot(r_spco_pla10, gr_spco_norm_pla10, label = "PLA10 Carbonyl O's")
#plt.plot(r_speo_pla10, gr_speo_norm_pla10, label = "PLA10 Ether O's")
#plt.plot(r_spac_pet3, gr_spac_norm_pet3, label = "PET3 Aromatic C's")
#plt.plot(r_spco_pet3, gr_spco_norm_pet3, label = "PET3 Carbonyl O's")
#plt.plot(r_speo_pet3, gr_speo_norm_pet3, label = "PET3 Ether O's")
plt.xlim([0,4])
plt.xticks(fontsize=18)
#plt.ylim([-2,42])
plt.ylim([-0.002,0.062])
#plt.yticks([0,10,20,30,40],fontsize=18)
plt.yticks(fontsize=18)
plt.legend(fontsize = 16, loc = 'upper right', frameon = False)
plt.xlabel('Distance (nm)', fontsize = 20)
#plt.ylabel('g(r)', fontsize = 20)
plt.ylabel('Normalized g(r)', fontsize = 20)
plt.title('Mass Distribution of Polymer From Alumina Surface', fontsize = 20)
plt.savefig("rdf-surf_polymer_norm.svg", bbox_inches='tight')
plt.show()
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'Arial'

from sklearn import preprocessing
import numpy as np

def moving_average(interval,window_size):
    window = np.ones(int(window_size))/float(window_size)
    return np.convolve(interval,window,'same')

gr_sp_arr_pla5 = moving_average(np.array(gr_sp_pla5),10)
gr_ss_arr_pla5 = np.array(gr_ss_pla5)
gr_spmc_arr_pla5 = moving_average(np.array(gr_spmc_pla5),20)
gr_spco_arr_pla5 = moving_average(np.array(gr_spco_pla5),20)
gr_speo_arr_pla5 = moving_average(np.array(gr_speo_pla5),20)
gr_sseo_arr_pla5 = np.array(gr_sseo_pla5)
gr_sp_norm_pla5 = preprocessing.normalize([gr_sp_arr_pla5]).reshape((len(gr_sp_pla5),1))
gr_ss_norm_pla5 = preprocessing.normalize([gr_ss_arr_pla5]).reshape((len(gr_ss_pla5),1))
gr_spmc_norm_pla5 = preprocessing.normalize([gr_spmc_arr_pla5]).reshape((len(gr_spmc_pla5),1))
gr_spco_norm_pla5 = preprocessing.normalize([gr_spco_arr_pla5]).reshape((len(gr_spco_pla5),1))
gr_speo_norm_pla5 = preprocessing.normalize([gr_speo_arr_pla5]).reshape((len(gr_speo_pla5),1))
gr_sseo_norm_pla5 = preprocessing.normalize([gr_sseo_arr_pla5]).reshape((len(gr_sseo_pla5),1))
gr_sp_arr_pet2 = moving_average(np.array(gr_sp_pet2),10)
gr_ss_arr_pet2 = np.array(gr_ss_pet2)
gr_spac_arr_pet2 = moving_average(np.array(gr_spac_pet2),20)
gr_spco_arr_pet2 = moving_average(np.array(gr_spco_pet2),20)
gr_speo_arr_pet2 = moving_average(np.array(gr_speo_pet2),20)
gr_sseo_arr_pet2 = np.array(gr_sseo_pet2)
gr_sp_norm_pet2 = preprocessing.normalize([gr_sp_arr_pet2]).reshape((len(gr_sp_pet2),1))
gr_ss_norm_pet2 = preprocessing.normalize([gr_ss_arr_pet2]).reshape((len(gr_ss_pet2),1))
gr_spac_norm_pet2 = preprocessing.normalize([gr_spac_arr_pet2]).reshape((len(gr_spac_pet2),1))
gr_spco_norm_pet2 = preprocessing.normalize([gr_spco_arr_pet2]).reshape((len(gr_spco_pet2),1))
gr_speo_norm_pet2 = preprocessing.normalize([gr_speo_arr_pet2]).reshape((len(gr_speo_pet2),1))
gr_sseo_norm_pet2 = preprocessing.normalize([gr_sseo_arr_pet2]).reshape((len(gr_sseo_pet2),1))
gr_sp_arr_pla10 = moving_average(np.array(gr_sp_pla10),10)
gr_ss_arr_pla10 = np.array(gr_ss_pla10)
gr_spmc_arr_pla10 = moving_average(np.array(gr_spmc_pla10),20)
gr_spco_arr_pla10 = moving_average(np.array(gr_spco_pla10),20)
gr_speo_arr_pla10 = moving_average(np.array(gr_speo_pla10),20)
gr_sseo_arr_pla10 = np.array(gr_sseo_pla10)
gr_sp_norm_pla10 = preprocessing.normalize([gr_sp_arr_pla10]).reshape((len(gr_sp_pla10),1))
gr_ss_norm_pla10 = preprocessing.normalize([gr_ss_arr_pla10]).reshape((len(gr_ss_pla10),1))
gr_spmc_norm_pla10 = preprocessing.normalize([gr_spmc_arr_pla10]).reshape((len(gr_spmc_pla10),1))
gr_spco_norm_pla10 = preprocessing.normalize([gr_spco_arr_pla10]).reshape((len(gr_spco_pla10),1))
gr_speo_norm_pla10 = preprocessing.normalize([gr_speo_arr_pla10]).reshape((len(gr_speo_pla10),1))
gr_sseo_norm_pla10 = preprocessing.normalize([gr_sseo_arr_pla10]).reshape((len(gr_sseo_pla10),1))
gr_sp_arr_pet3 = moving_average(np.array(gr_sp_pet3),10)
gr_ss_arr_pet3 = np.array(gr_ss_pet3)
gr_spac_arr_pet3 = moving_average(np.array(gr_spac_pet3),20)
gr_spco_arr_pet3 = moving_average(np.array(gr_spco_pet3),20)
gr_speo_arr_pet3 = moving_average(np.array(gr_speo_pet3),20)
gr_sseo_arr_pet3 = np.array(gr_sseo_pet3)
gr_sp_norm_pet3 = preprocessing.normalize([gr_sp_arr_pet3]).reshape((len(gr_sp_pet3),1))
gr_ss_norm_pet3 = preprocessing.normalize([gr_ss_arr_pet3]).reshape((len(gr_ss_pet3),1))
gr_spac_norm_pet3 = preprocessing.normalize([gr_spac_arr_pet3]).reshape((len(gr_spac_pet3),1))
gr_spco_norm_pet3 = preprocessing.normalize([gr_spco_arr_pet3]).reshape((len(gr_spco_pet3),1))
gr_speo_norm_pet3 = preprocessing.normalize([gr_speo_arr_pet3]).reshape((len(gr_speo_pet3),1))
gr_sseo_norm_pet3 = preprocessing.normalize([gr_sseo_arr_pet3]).reshape((len(gr_sseo_pet3),1))

gr_ssrc_arr_pla5 = np.array(gr_ssrc_pla5)
gr_ssrc_norm_pla5 = preprocessing.normalize([gr_ssrc_arr_pla5]).reshape((len(gr_ssrc_pla5),1))

plt.figure(figsize = (15, 8))
plt.plot(r_sp_pla5, gr_sp_norm_pla5, label = "PLA5", color = "red", linewidth = 3)
plt.plot(r_sp_pet2, gr_sp_norm_pet2, label = "PET2", color = "green", linewidth = 3)
plt.plot(r_sp_pla10, gr_sp_norm_pla10, label = "PLA10", color = "orange", linewidth = 3)
plt.plot(r_sp_pet3, gr_sp_norm_pet3, label = "PET3", color = "blue", linewidth = 3)
#plt.plot(r_spmc_pla5, gr_spmc_norm_pla5, label = "PLA5 Methyl C's")
#plt.plot(r_spco_pla5, gr_spco_norm_pla5, label = "PLA5 Carbonyl O's")
#plt.plot(r_speo_pla5, gr_speo_norm_pla5, label = "PLA5 Ether O's")
#plt.plot(r_spac_pet2, gr_spac_norm_pet2, label = "PET2 Aromatic C's")
#plt.plot(r_spco_pet2, gr_spco_norm_pet2, label = "PET2 Carbonyl O's")
#plt.plot(r_speo_pet2, gr_speo_norm_pet2, label = "PET2 Ether O's")
#plt.plot(r_spmc_pla10, gr_spmc_norm_pla10, label = "PLA10 Methyl C's")
#plt.plot(r_spco_pla10, gr_spco_norm_pla10, label = "PLA10 Carbonyl O's")
#plt.plot(r_speo_pla10, gr_speo_norm_pla10, label = "PLA10 Ether O's")
#plt.plot(r_spac_pet3, gr_spac_norm_pet3, label = "PET3 Aromatic C's")
#plt.plot(r_spco_pet3, gr_spco_norm_pet3, label = "PET3 Carbonyl O's")
#plt.plot(r_speo_pet3, gr_speo_norm_pet3, label = "PET3 Ether O's")
plt.xlim([0,4])
plt.xticks(fontsize=18)
#plt.ylim([-2,42])
plt.ylim([-0.002,0.062])
#plt.yticks([0,10,20,30,40],fontsize=18)
plt.yticks(fontsize=18)
plt.legend(fontsize = 16, loc = 'upper right', frameon = False)
plt.xlabel('Distance (nm)', fontsize = 20)
#plt.ylabel('g(r)', fontsize = 20)
plt.ylabel('Normalized g(r)', fontsize = 20)
plt.title('Mass Distribution of Polymer From Alumina Surface', fontsize = 20)
plt.savefig("rdf-surf_polymer_norm_new.svg", bbox_inches='tight')
plt.show()

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'Arial'

from sklearn import preprocessing
import matplotlib.pyplot as plt
import numpy as np

r_ss_unbiased_pla5, gr_ss_unbiased_pla5 = np.loadtxt("rdf-surf_surface_solvent_nopbc_new_unbiased_pla5.xvg", comments=["@","#"], unpack=True)
r_ss_adsorbed_pla5, gr_ss_adsorbed_pla5 = np.loadtxt("rdf-surf_surface_solvent_nopbc_sd_adsorbed_pla5.xvg", comments=["@","#"], unpack=True)
r_ss_bulk_pla5, gr_ss_bulk_pla5 = np.loadtxt("rdf-surf_surface_solvent_nopbc_sd_bulk_pla5.xvg", comments=["@","#"], unpack=True)

def moving_average(interval,window_size):
    window = np.ones(int(window_size))/float(window_size)
    return np.convolve(interval,window,'same')
    
gr_ss_unbiased_arr_pla5 = moving_average(np.array(gr_ss_unbiased_pla5),10)
gr_ss_unbiased_norm_pla5 = preprocessing.normalize([gr_ss_unbiased_arr_pla5]).reshape((len(gr_ss_unbiased_pla5),1))
gr_ss_adsorbed_arr_pla5 = moving_average(np.array(gr_ss_adsorbed_pla5),10)
gr_ss_adsorbed_norm_pla5 = preprocessing.normalize([gr_ss_adsorbed_arr_pla5]).reshape((len(gr_ss_adsorbed_pla5),1))
gr_ss_bulk_arr_pla5 = moving_average(np.array(gr_ss_bulk_pla5),10)
gr_ss_bulk_norm_pla5 = preprocessing.normalize([gr_ss_bulk_arr_pla5]).reshape((len(gr_ss_bulk_pla5),1))

plt.figure(figsize = (15, 5))
plt.plot(r_ss_pla5, gr_ss_pla5, label = "WTM", color = "black", linewidth = 2.5,alpha=1)
plt.plot(r_ss_unbiased_pla5, gr_ss_unbiased_pla5, label = "Unbiased", color = "blue", linewidth = 2.5,alpha=0.9)
#plt.plot(r_ss_adsorbed_pla5, gr_ss_adsorbed_norm_pla5, label = "WTM Adsorbed", color = "red", linewidth = 2.5,alpha=0.8)
#plt.plot(r_ss_bulk_pla5, gr_ss_bulk_norm_pla5 , label = "WTM Bulk", color = "green", linewidth = 2.5,alpha=0.7)
##plt.vlines(0.270, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
##plt.vlines(0.400, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(0.570, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(1.010, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(1.465, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(1.925, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(2.370, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(2.825, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(0.205, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(0.415, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(0.660, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(1.130, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(1.595, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(2.060, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(2.530, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(3.000, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
plt.xlim([0,4])
plt.xticks(fontsize=18)
plt.ylim([-200,5200])
#plt.ylim([-0.001,0.031])
plt.yticks([0,1000,2000,3000,4000,5000],fontsize=18)
#plt.yticks(fontsize=18)
plt.legend(fontsize = 16, loc = 'lower right', frameon = False)
plt.xlabel('Distance (nm)', fontsize = 20)
#plt.ylabel('g(r)', fontsize = 20)
plt.ylabel('g(r)', fontsize = 20)
plt.title('Solvent Mass Density Distribution WTM-Unbiased Comparison (Al$_{2}$O$_{3}$-14DO-PLA5)', fontsize = 20)
plt.savefig("rdf-surf_solvent_comparison_unbiased_wtm.svg", bbox_inches='tight')
plt.show()

plt.figure(figsize = (15, 6))
plt.plot(r_ss_pla5, gr_ss_norm_pla5, label = "WTM", color = "black", linewidth = 2.5,alpha=1)
plt.plot(r_ss_unbiased_pla5, gr_ss_unbiased_norm_pla5, label = "Unbiased", color = "blue", linewidth = 2.5,alpha=0.9)
#plt.plot(r_ss_adsorbed_pla5, gr_ss_adsorbed_norm_pla5, label = "WTM Adsorbed", color = "red", linewidth = 2.5,alpha=0.8)
#plt.plot(r_ss_bulk_pla5, gr_ss_bulk_norm_pla5 , label = "WTM Bulk", color = "green", linewidth = 2.5,alpha=0.7)
##plt.vlines(0.270, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
##plt.vlines(0.400, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(0.570, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(1.010, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(1.465, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(1.925, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(2.370, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(2.825, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(0.205, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(0.415, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(0.660, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(1.130, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(1.595, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(2.060, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(2.530, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(3.000, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
plt.xlim([0,4])
plt.xticks(fontsize=18)
#plt.ylim([-200,5200])
plt.ylim([-0.001,0.031])
#plt.yticks([0,1000,2000,3000,4000,5000],fontsize=18)
plt.yticks(fontsize=18)
plt.legend(fontsize = 16, loc = 'lower right', frameon = False)
plt.xlabel('Distance (nm)', fontsize = 20)
#plt.ylabel('g(r)', fontsize = 20)
plt.ylabel('Normalized g(r)', fontsize = 20)
plt.title('Solvent Mass Density Distribution WTM-Unbiased Comparison (Al$_{2}$O$_{3}$-14DO-PLA5)', fontsize = 20)
plt.savefig("rdf-surf_solvent_norm_comparison_unbiased_wtm.svg", bbox_inches='tight')
plt.show()

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'Arial'

from sklearn import preprocessing
import numpy as np

def moving_average(interval,window_size):
    window = np.ones(int(window_size))/float(window_size)
    return np.convolve(interval,window,'same')


r_ss_pla5 = r_ss_pla5[:2001]
r_sseo_pla5 = r_sseo_pla5[:2001]
r_ssrc_pla5 = r_ssrc_pla5[:2001]

gr_ss_arr_pla5 = np.array(gr_ss_pla5[:2001])
gr_ss_arr_pla5_trim = np.trim_zeros(gr_ss_arr_pla5)
gr_ss_arr_pla5_trim_sum = np.sum(gr_ss_arr_pla5_trim)
gr_ss_arr_pla5_trim_avg = gr_ss_arr_pla5_trim_sum/gr_ss_arr_pla5_trim.size
scaling_factor_pla5 = gr_ss_arr_pla5_trim_avg/1
gr_ss_norm_pla5 = gr_ss_arr_pla5/scaling_factor_pla5

gr_sseo_arr_pla5 = np.array(gr_sseo_pla5[:2001])
gr_sseo_arr_pla5_trim = np.trim_zeros(gr_sseo_arr_pla5)
gr_sseo_arr_pla5_trim_sum = np.sum(gr_sseo_arr_pla5_trim)
gr_sseo_arr_pla5_trim_avg = gr_sseo_arr_pla5_trim_sum/gr_sseo_arr_pla5_trim.size
scaling_factor_pla5 = gr_sseo_arr_pla5_trim_avg/1
gr_sseo_norm_pla5 = gr_sseo_arr_pla5/scaling_factor_pla5

gr_ssrc_arr_pla5 = np.array(gr_ssrc_pla5[:2001])
gr_ssrc_arr_pla5_trim = np.trim_zeros(gr_ssrc_arr_pla5)
gr_ssrc_arr_pla5_trim_sum = np.sum(gr_ssrc_arr_pla5_trim)
gr_ssrc_arr_pla5_trim_avg = gr_ssrc_arr_pla5_trim_sum/gr_ssrc_arr_pla5_trim.size
scaling_factor_pla5 = gr_ssrc_arr_pla5_trim_avg/1
gr_ssrc_norm_pla5 = gr_ssrc_arr_pla5/scaling_factor_pla5

plt.figure(figsize = (15, 6))
plt.plot(r_ss_pla5, gr_ss_norm_pla5, label = "14DO COM", color = "black", linewidth = 3)
plt.plot(r_sseo_pla5, gr_sseo_norm_pla5, label = "14DO Ether O", color = "red", linewidth = 3)
plt.plot(r_ssrc_pla5, gr_ssrc_norm_pla5, label = "14DO Methylene C", color = "green", linewidth = 3)
##plt.vlines(0.270, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
##plt.vlines(0.400, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(0.570, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(1.010, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(1.465, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(1.925, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(2.370, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(2.825, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(0.205, -0.1, 5.1, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(0.340, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(0.420, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.vlines(0.490, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(0.660, -0.1, 5.1, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(1.130, -0.1, 5.1, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(1.595, -0.1, 5.1, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(2.060, -0.1, 5.1, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(2.530, -0.1, 5.1, colors = 'blue', linestyles = 'dotted', linewidth = 3)
plt.vlines(3.000, -0.1, 5.1, colors = 'blue', linestyles = 'dotted', linewidth = 3)
#plt.hlines(1, -1, 5, linewidth = 1, linestyle = "dashed", color = 'black')
plt.xlim([0,4])
plt.xticks(fontsize=18)
#plt.ylim([-200,5200])
plt.ylim([-0.1,3.15])
plt.yticks([0,0.5,1,1.5,2,2.5,3.0],fontsize=18)
#plt.yticks([0,1000,2000,3000,4000,5000],fontsize=18)
plt.yticks(fontsize=18)
plt.legend(fontsize = 16, loc = 'lower right', frameon = False)
plt.xlabel('Distance (nm)', fontsize = 20)
#plt.ylabel('g(z)', fontsize = 20)
plt.ylabel('        g(z)', fontsize = 20)
plt.title('Atom Number Density Distribution of Solvent From Alumina Surface', fontsize = 20)
plt.savefig("rdf-surf_solvent_2_num_dens.svg", bbox_inches='tight')
plt.savefig("rdf-surf_solvent_2_num_dens_trans.svg", bbox_inches='tight',transparent=True)
plt.show()

r_sp_pla5 = r_sp_pla5[:2005]
r_sp_pet2 = r_sp_pet2[:2005]
r_sp_pla10 = r_sp_pla10[:2005]
r_sp_pet3 = r_sp_pet3[:2005]

gr_sp_arr_pla5 = moving_average(np.array(gr_sp_pla5[:2005]),5)
gr_sp_arr_pla5_trim = np.trim_zeros(gr_sp_arr_pla5)
gr_sp_arr_pla5_trim_sum = np.sum(gr_sp_arr_pla5_trim)
gr_sp_arr_pla5_trim_avg = gr_sp_arr_pla5_trim_sum/gr_sp_arr_pla5_trim.size
scaling_factor_pla5 = gr_sp_arr_pla5_trim_avg/1
gr_sp_norm_pla5 = gr_sp_arr_pla5/scaling_factor_pla5

gr_sp_arr_pet2 = moving_average(np.array(gr_sp_pet2[:2005]),5)
gr_sp_arr_pet2_trim = np.trim_zeros(gr_sp_arr_pet2)
gr_sp_arr_pet2_trim_sum = np.sum(gr_sp_arr_pet2_trim)
gr_sp_arr_pet2_trim_avg = gr_sp_arr_pet2_trim_sum/gr_sp_arr_pet2_trim.size
scaling_factor_pet2 = gr_sp_arr_pet2_trim_avg/1
gr_sp_norm_pet2 = gr_sp_arr_pet2/scaling_factor_pet2

gr_sp_arr_pla10 = moving_average(np.array(gr_sp_pla10[:2005]),5)
gr_sp_arr_pla10_trim = np.trim_zeros(gr_sp_arr_pla10)
gr_sp_arr_pla10_trim_sum = np.sum(gr_sp_arr_pla10_trim)
gr_sp_arr_pla10_trim_avg = gr_sp_arr_pla10_trim_sum/gr_sp_arr_pla10_trim.size
scaling_factor_pla10 = gr_sp_arr_pla10_trim_avg/1
gr_sp_norm_pla10 = gr_sp_arr_pla10/scaling_factor_pla10

gr_sp_arr_pet3 = moving_average(np.array(gr_sp_pet3[:2005]),5)
gr_sp_arr_pet3_trim = np.trim_zeros(gr_sp_arr_pet3)
gr_sp_arr_pet3_trim_sum = np.sum(gr_sp_arr_pet3_trim)
gr_sp_arr_pet3_trim_avg = gr_sp_arr_pet3_trim_sum/gr_sp_arr_pet3_trim.size
scaling_factor_pet3 = gr_sp_arr_pet3_trim_avg/1
gr_sp_norm_pet3 = gr_sp_arr_pet3/scaling_factor_pet3

plt.figure(figsize = (15, 6))
plt.plot(r_sp_pla5, gr_sp_norm_pla5, label = "PLA5", color = "red", linewidth = 3)
plt.plot(r_sp_pet2, gr_sp_norm_pet2, label = "PET2", color = "green", linewidth = 3)
plt.plot(r_sp_pla10, gr_sp_norm_pla10, label = "PLA10", color = "orange", linewidth = 3)
plt.plot(r_sp_pet3, gr_sp_norm_pet3, label = "PET3", color = "blue", linewidth = 3)
#plt.plot(r_spmc_pla5, gr_spmc_norm_pla5, label = "PLA5 Methyl C's")
#plt.plot(r_spco_pla5, gr_spco_norm_pla5, label = "PLA5 Carbonyl O's")
#plt.plot(r_speo_pla5, gr_speo_norm_pla5, label = "PLA5 Ether O's")
#plt.plot(r_spac_pet2, gr_spac_norm_pet2, label = "PET2 Aromatic C's")
#plt.plot(r_spco_pet2, gr_spco_norm_pet2, label = "PET2 Carbonyl O's")
#plt.plot(r_speo_pet2, gr_speo_norm_pet2, label = "PET2 Ether O's")
#plt.plot(r_spmc_pla10, gr_spmc_norm_pla10, label = "PLA10 Methyl C's")
#plt.plot(r_spco_pla10, gr_spco_norm_pla10, label = "PLA10 Carbonyl O's")
#plt.plot(r_speo_pla10, gr_speo_norm_pla10, label = "PLA10 Ether O's")
#plt.plot(r_spac_pet3, gr_spac_norm_pet3, label = "PET3 Aromatic C's")
#plt.plot(r_spco_pet3, gr_spco_norm_pet3, label = "PET3 Carbonyl O's")
#plt.plot(r_speo_pet3, gr_speo_norm_pet3, label = "PET3 Ether O's")
#plt.hlines(1, -1, 5, linewidth = 1, linestyle = "dashed", color = 'black')
plt.xlim([0,4])
plt.xticks(fontsize=18)
#plt.ylim([-2,42])
plt.ylim([-0.1,3.15])
plt.yticks([0,0.5,1,1.5,2,2.5,3.0],fontsize=18)
#plt.yticks([0,10,20,30,40],fontsize=18)
plt.yticks(fontsize=18)
plt.legend(fontsize = 16, loc = 'upper right', frameon = False)
plt.xlabel('Distance (nm)', fontsize = 20)
#plt.ylabel('g(z)', fontsize = 20)
plt.ylabel('g(z)', fontsize = 20)
plt.title('Atom Number Density Distribution of Polymer From Alumina Surface', fontsize = 20)
plt.savefig("rdf-surf_polymer_num_dens.svg", bbox_inches='tight')
plt.savefig("rdf-surf_polymer_num_dens_trans.svg", bbox_inches='tight',transparent=True)
plt.show()

# %%
import csv

r_sp_pla5, gr_sp_norm_pla5
r_sp_pet2, gr_sp_norm_pet2
r_sp_pla10, gr_sp_norm_pla10
r_sp_pet3, gr_sp_norm_pet3
# File name
data = list(zip(r_sp_pla5, gr_sp_norm_pla5, r_sp_pet2, gr_sp_norm_pet2, r_sp_pla10, gr_sp_norm_pla10, r_sp_pet3, gr_sp_norm_pet3))

# Input column headers
column_names = input("Enter 8 column names separated by commas: ").split(',')

# Validate number of headers
if len(column_names) != 8:
    raise ValueError("You must enter exactly 8 column names.")

# Save to CSV
filename = 'density_data_efri_single_polyester_ms_fig_s10.csv'
with open(filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(column_names)
    writer.writerows(data)

print(f"Saved 8 arrays as columns in '{filename}'")
# Out:
# Enter 8 column names separated by commas:  z_pla5,gz_pla5,z_pet2,gz_pet2,z_pla10,gz_pla10,z_pet3,gz_pet3
# Saved 8 arrays as columns in 'density_data_efri_single_polyester_ms_fig_s10.csv'

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'Arial'

from sklearn import preprocessing
import matplotlib.pyplot as plt
import numpy as np

r_ss_unbiased_pla5, gr_ss_unbiased_pla5 = np.loadtxt("rdf-surf_surface_solvent_nopbc_new_unbiased_pla5.xvg", comments=["@","#"], unpack=True)

r_ss_pla5 = r_ss_pla5[:2001]
r_ss_unbiased_pla5 = r_ss_unbiased_pla5[:2001]

gr_ss_arr_pla5 = np.array(gr_ss_pla5[:2001])
gr_ss_arr_pla5_trim = np.trim_zeros(gr_ss_arr_pla5)
gr_ss_arr_pla5_trim_sum = np.sum(gr_ss_arr_pla5_trim)
gr_ss_arr_pla5_trim_avg = gr_ss_arr_pla5_trim_sum/gr_ss_arr_pla5_trim.size
scaling_factor_pla5 = gr_ss_arr_pla5_trim_avg/1
gr_ss_norm_pla5 = gr_ss_arr_pla5/scaling_factor_pla5

gr_ss_unbiased_arr_pla5 = np.array(gr_ss_unbiased_pla5[:2001])
gr_ss_unbiased_arr_pla5_trim = np.trim_zeros(gr_ss_unbiased_arr_pla5)
gr_ss_unbiased_arr_pla5_trim_sum = np.sum(gr_ss_unbiased_arr_pla5_trim)
gr_ss_unbiased_arr_pla5_trim_avg = gr_ss_unbiased_arr_pla5_trim_sum/gr_ss_unbiased_arr_pla5_trim.size
scaling_factor_pla5 = gr_ss_unbiased_arr_pla5_trim_avg/1
gr_ss_unbiased_norm_pla5 = gr_ss_unbiased_arr_pla5/scaling_factor_pla5

plt.figure(figsize = (15, 5))
plt.plot(r_ss_pla5, gr_ss_norm_pla5, label = "WTM", color = "black", linewidth = 6,alpha=1)
plt.plot(r_ss_unbiased_pla5, gr_ss_unbiased_norm_pla5, label = "Unbiased", color = "blue", linewidth = 2.5,alpha=1)
#plt.plot(r_ss_adsorbed_pla5, gr_ss_adsorbed_norm_pla5, label = "WTM Adsorbed", color = "red", linewidth = 2.5,alpha=0.8)
#plt.plot(r_ss_bulk_pla5, gr_ss_bulk_norm_pla5 , label = "WTM Bulk", color = "green", linewidth = 2.5,alpha=0.7)
##plt.vlines(0.270, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
##plt.vlines(0.400, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(0.570, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(1.010, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(1.465, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(1.925, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(2.370, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(2.825, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(0.205, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(0.415, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(0.660, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(1.130, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(1.595, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(2.060, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(2.530, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.vlines(3.000, -0.1, 0.055, colors = 'blue', linestyles = 'dotted', linewidth = 2)
#plt.hlines(1, -1, 5, linewidth = 1, linestyle = "dashed", color = 'black')
plt.xlim([0,4])
plt.xticks(fontsize=18)
#plt.ylim([-200,5200])
plt.ylim([-0.1,1.6])
plt.yticks([0,0.5,1,1.5],fontsize=18)
#plt.yticks([0,1000,2000,3000,4000,5000],fontsize=18)
plt.yticks(fontsize=18)
plt.legend(fontsize = 16, loc = 'upper right', frameon = False)
plt.xlabel('Distance (nm)', fontsize = 20)
#plt.ylabel('g(r)', fontsize = 20)
plt.ylabel('g(z)', fontsize = 20)
plt.title('Solvent Atom Number Density Distribution WTM-Unbiased Comparison (Al$_{2}$O$_{3}$-14DO-PLA5)', fontsize = 20)
plt.savefig("rdf-surf_solvent_norm_comparison_unbiased_wtm_num_dens.svg", bbox_inches='tight')
plt.savefig("rdf-surf_solvent_norm_comparison_unbiased_wtm_num_dens_trans.svg", bbox_inches='tight',transparent=True)
plt.show()
