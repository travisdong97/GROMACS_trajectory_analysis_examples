# %%
import MDAnalysis as mda
from MDAnalysis.analysis import dihedrals
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

u = mda.Universe('../../BSA-BSA/BSA-BSA.pdb')
BSA_BSA = u.select_atoms('protein')
BSA1 = BSA_BSA[range(0,9219)]
BSA2 = BSA_BSA[range(9219,18438)]
BSA_BSA_com = BSA_BSA.center_of_mass(compound='residues')
BSA1_com = BSA1.center_of_mass(compound='residues')
BSA2_com = BSA2.center_of_mass(compound='residues')
n_BSA_BSA = len(BSA_BSA_com)
n_BSA1 = len(BSA1_com)
n_BSA2 = len(BSA2_com)
print('BSA-BSA has {} resisudes and BSA1 has {} residues and BSA2 has {} residues'.format(n_BSA_BSA, n_BSA1, n_BSA2))
rama = dihedrals.Ramachandran(BSA_BSA).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
plt.title('Ramachandran Plot - BSA-BSA')
plt.show()

u = mda.Universe('../../BSA-BSA_powder/md_resnr.gro')
BSA_BSA = u.select_atoms('protein')
BSA1 = u.select_atoms('resid 1-583')
BSA2 = u.select_atoms('resid 584-1166')
BSA_BSA_com = BSA_BSA.center_of_mass(compound='residues')
BSA1_com = BSA1.center_of_mass(compound='residues')
BSA2_com = BSA2.center_of_mass(compound='residues')
n_BSA_BSA = len(BSA_BSA_com)
n_BSA1 = len(BSA1_com)
n_BSA2 = len(BSA2_com)
print('BSA-BSA has {} resisudes and BSA1 has {} residues and BSA2 has {} residues'.format(n_BSA_BSA, n_BSA1, n_BSA2))
rama = dihedrals.Ramachandran(BSA_BSA).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
plt.title('Ramachandran Plot - BSA-BSA (Powder)')
plt.show()

u = mda.Universe('../../BSA-BSA-402x_Cellulose6_powder/md_resnr.gro')
BSA_BSA = u.select_atoms('protein')
BSA1 = u.select_atoms('resid 1-583')
BSA2 = u.select_atoms('resid 584-1166')
BSA_BSA_com = BSA_BSA.center_of_mass(compound='residues')
BSA1_com = BSA1.center_of_mass(compound='residues')
BSA2_com = BSA2.center_of_mass(compound='residues')
n_BSA_BSA = len(BSA_BSA_com)
n_BSA1 = len(BSA1_com)
n_BSA2 = len(BSA2_com)
print('BSA-BSA has {} resisudes and BSA1 has {} residues and BSA2 has {} residues'.format(n_BSA_BSA, n_BSA1, n_BSA2))
rama = dihedrals.Ramachandran(BSA_BSA).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
plt.title('Ramachandran Plot - 60-20 wt% αCell-BSA (Powder)')
plt.show()

u = mda.Universe('../../BSA-BSA-402x_Cellulose6-292x_SRB-186x_STA_powder/md_resnr.gro')
BSA_BSA = u.select_atoms('protein')
BSA1 = u.select_atoms('resid 1-583')
BSA2 = u.select_atoms('resid 584-1166')
BSA_BSA_com = BSA_BSA.center_of_mass(compound='residues')
BSA1_com = BSA1.center_of_mass(compound='residues')
BSA2_com = BSA2.center_of_mass(compound='residues')
n_BSA_BSA = len(BSA_BSA_com)
n_BSA1 = len(BSA1_com)
n_BSA2 = len(BSA2_com)
print('BSA-BSA has {} resisudes and BSA1 has {} residues and BSA2 has {} residues'.format(n_BSA_BSA, n_BSA1, n_BSA2))
rama = dihedrals.Ramachandran(BSA_BSA).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
plt.title('Ramachandran Plot - 60-20-10-10 wt% αCell-BSA-PL-FA (Powder)')
plt.show()
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# /Users/zido2651/opt/anaconda3/lib/python3.9/site-packages/MDAnalysis/topology/PDBParser.py:331: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using MDAnalysis.topology.guessers.
#   warnings.warn("Element information is missing, elements attribute "
# /Users/zido2651/opt/anaconda3/lib/python3.9/site-packages/MDAnalysis/analysis/dihedrals.py:407: UserWarning: Cannot determine phi and psi angles for the first or last residues
#   warnings.warn("Cannot determine phi and psi angles for the first "
# /Users/zido2651/opt/anaconda3/lib/python3.9/site-packages/MDAnalysis/analysis/dihedrals.py:417: UserWarning: Some residues in selection do not have phi or psi selections
#   warnings.warn("Some residues in selection do not have "
# ...

# %%
import MDAnalysis as mda
from MDAnalysis.analysis import dihedrals
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

u = mda.Universe('../../BSA_b-BSA_b/BSA_b-BSA_b.pdb')
BSA_b_BSA_b = u.select_atoms('protein')
BSA_b1 = BSA_b_BSA_b[range(0,9219)]
BSA_b2 = BSA_b_BSA_b[range(9219,18438)]
BSA_b_BSA_b_com = BSA_b_BSA_b.center_of_mass(compound='residues')
BSA_b1_com = BSA_b1.center_of_mass(compound='residues')
BSA_b2_com = BSA_b2.center_of_mass(compound='residues')
n_BSA_b_BSA_b = len(BSA_b_BSA_b_com)
n_BSA_b1 = len(BSA_b1_com)
n_BSA_b2 = len(BSA_b2_com)
print('BSA_b-BSA_b has {} resisudes and BSA_b1 has {} residues and BSA_b2 has {} residues'.format(n_BSA_b_BSA_b, n_BSA_b1, n_BSA_b2))
rama = dihedrals.Ramachandran(BSA_b_BSA_b).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
plt.title('Ramachandran Plot - BSAb-BSAb')
plt.show()

u = mda.Universe('../../BSA_b-BSA_b_powder/md_resnr.gro')
BSA_b_BSA_b = u.select_atoms('protein')
BSA_b1 = u.select_atoms('resid 1-583')
BSA_b2 = u.select_atoms('resid 584-1166')
BSA_b_BSA_b_com = BSA_b_BSA_b.center_of_mass(compound='residues')
BSA_b1_com = BSA_b1.center_of_mass(compound='residues')
BSA_b2_com = BSA_b2.center_of_mass(compound='residues')
n_BSA_b_BSA_b = len(BSA_b_BSA_b_com)
n_BSA_b1 = len(BSA_b1_com)
n_BSA_b2 = len(BSA_b2_com)
print('BSA_b-BSA_b has {} resisudes and BSA_b1 has {} residues and BSA_b2 has {} residues'.format(n_BSA_b_BSA_b, n_BSA_b1, n_BSA_b2))
rama = dihedrals.Ramachandran(BSA_b_BSA_b).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
plt.title('Ramachandran Plot - BSAb-BSAb (Powder)')
plt.show()

u = mda.Universe('../../BSA_b-BSA_b-402x_Cellulose6_powder/md_resnr.gro')
BSA_b_BSA_b = u.select_atoms('protein')
BSA_b1 = u.select_atoms('resid 1-583')
BSA_b2 = u.select_atoms('resid 584-1166')
BSA_b_BSA_b_com = BSA_b_BSA_b.center_of_mass(compound='residues')
BSA_b1_com = BSA_b1.center_of_mass(compound='residues')
BSA_b2_com = BSA_b2.center_of_mass(compound='residues')
n_BSA_b_BSA_b = len(BSA_b_BSA_b_com)
n_BSA_b1 = len(BSA_b1_com)
n_BSA_b2 = len(BSA_b2_com)
print('BSA_b-BSA_b has {} resisudes and BSA_b1 has {} residues and BSA_b2 has {} residues'.format(n_BSA_b_BSA_b, n_BSA_b1, n_BSA_b2))
rama = dihedrals.Ramachandran(BSA_b_BSA_b).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
plt.title('Ramachandran Plot - 60-20 wt% αCell-BSAb (Powder)')
plt.show()

u = mda.Universe('../../BSA_b-BSA_b-402x_Cellulose6-292x_SRB-186x_STA_powder/md_resnr.gro')
BSA_b_BSA_b = u.select_atoms('protein')
BSA_b1 = u.select_atoms('resid 1-583')
BSA_b2 = u.select_atoms('resid 584-1166')
BSA_b_BSA_b_com = BSA_b_BSA_b.center_of_mass(compound='residues')
BSA_b1_com = BSA_b1.center_of_mass(compound='residues')
BSA_b2_com = BSA_b2.center_of_mass(compound='residues')
n_BSA_b_BSA_b = len(BSA_b_BSA_b_com)
n_BSA_b1 = len(BSA_b1_com)
n_BSA_b2 = len(BSA_b2_com)
print('BSA_b-BSA_b has {} resisudes and BSA_b1 has {} residues and BSA_b2 has {} residues'.format(n_BSA_b_BSA_b, n_BSA_b1, n_BSA_b2))
rama = dihedrals.Ramachandran(BSA_b_BSA_b).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
plt.title('Ramachandran Plot - 60-20-10-10 wt% αCell-BSAb-PL-FA (Powder)')
plt.show()
# Out:
# BSA_b-BSA_b has 1166 resisudes and BSA_b1 has 583 residues and BSA_b2 has 583 residues
# (1, 1162, 2)
# BSA_b-BSA_b has 1166 resisudes and BSA_b1 has 583 residues and BSA_b2 has 583 residues
# (1, 1164, 2)
# BSA_b-BSA_b has 1166 resisudes and BSA_b1 has 583 residues and BSA_b2 has 583 residues
# (1, 1164, 2)
# BSA_b-BSA_b has 1166 resisudes and BSA_b1 has 583 residues and BSA_b2 has 583 residues
# (1, 1164, 2)

# %%
import MDAnalysis as mda
from MDAnalysis.analysis import dihedrals
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

u = mda.Universe('../../BSA-BSA/BSA-BSA.pdb')
BSA_BSA = u.select_atoms('protein')
BSA1 = BSA_BSA[range(0,9219)]
BSA2 = BSA_BSA[range(9219,18438)]
BSA_BSA_com = BSA_BSA.center_of_mass(compound='residues')
BSA1_com = BSA1.center_of_mass(compound='residues')
BSA2_com = BSA2.center_of_mass(compound='residues')
n_BSA_BSA = len(BSA_BSA_com)
n_BSA1 = len(BSA1_com)
n_BSA2 = len(BSA2_com)
print('BSA-BSA has {} resisudes and BSA1 has {} residues and BSA2 has {} residues'.format(n_BSA_BSA, n_BSA1, n_BSA2))
rama = dihedrals.Ramachandran(BSA_BSA).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
plt.title('Ramachandran Plot - BSA-BSA')
plt.show()

u = mda.Universe('../../BSA-BSA_pressed/md_resnr.gro')
BSA_BSA = u.select_atoms('protein')
BSA1 = u.select_atoms('resid 1-583')
BSA2 = u.select_atoms('resid 584-1166')
BSA_BSA_com = BSA_BSA.center_of_mass(compound='residues')
BSA1_com = BSA1.center_of_mass(compound='residues')
BSA2_com = BSA2.center_of_mass(compound='residues')
n_BSA_BSA = len(BSA_BSA_com)
n_BSA1 = len(BSA1_com)
n_BSA2 = len(BSA2_com)
print('BSA-BSA has {} resisudes and BSA1 has {} residues and BSA2 has {} residues'.format(n_BSA_BSA, n_BSA1, n_BSA2))
rama = dihedrals.Ramachandran(BSA_BSA).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
plt.title('Ramachandran Plot - BSA-BSA (Pressed)')
plt.show()

u = mda.Universe('../../BSA-BSA-402x_Cellulose6_pressed/md_resnr.gro')
BSA_BSA = u.select_atoms('protein')
BSA1 = u.select_atoms('resid 1-583')
BSA2 = u.select_atoms('resid 584-1166')
BSA_BSA_com = BSA_BSA.center_of_mass(compound='residues')
BSA1_com = BSA1.center_of_mass(compound='residues')
BSA2_com = BSA2.center_of_mass(compound='residues')
n_BSA_BSA = len(BSA_BSA_com)
n_BSA1 = len(BSA1_com)
n_BSA2 = len(BSA2_com)
print('BSA-BSA has {} resisudes and BSA1 has {} residues and BSA2 has {} residues'.format(n_BSA_BSA, n_BSA1, n_BSA2))
rama = dihedrals.Ramachandran(BSA_BSA).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
plt.title('Ramachandran Plot - 60-20 wt% αCell-BSA (Pressed)')
plt.show()

u = mda.Universe('../../BSA-BSA-402x_Cellulose6-292x_SRB-186x_STA_pressed/md_resnr.gro')
BSA_BSA = u.select_atoms('protein')
BSA1 = u.select_atoms('resid 1-583')
BSA2 = u.select_atoms('resid 584-1166')
BSA_BSA_com = BSA_BSA.center_of_mass(compound='residues')
BSA1_com = BSA1.center_of_mass(compound='residues')
BSA2_com = BSA2.center_of_mass(compound='residues')
n_BSA_BSA = len(BSA_BSA_com)
n_BSA1 = len(BSA1_com)
n_BSA2 = len(BSA2_com)
print('BSA-BSA has {} resisudes and BSA1 has {} residues and BSA2 has {} residues'.format(n_BSA_BSA, n_BSA1, n_BSA2))
rama = dihedrals.Ramachandran(BSA_BSA).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
plt.title('Ramachandran Plot - 60-20-10-10 wt% αCell-BSA-PL-FA (Pressed)')
plt.savefig("protein_protein_ramachandran.svg")
plt.show()
# Out:
# BSA-BSA has 1166 resisudes and BSA1 has 583 residues and BSA2 has 583 residues
# (1, 1162, 2)
# BSA-BSA has 1166 resisudes and BSA1 has 583 residues and BSA2 has 583 residues
# (1, 1164, 2)
# BSA-BSA has 1166 resisudes and BSA1 has 583 residues and BSA2 has 583 residues
# (1, 1164, 2)
# BSA-BSA has 1166 resisudes and BSA1 has 583 residues and BSA2 has 583 residues
# (1, 1164, 2)

# %%
import MDAnalysis as mda
from MDAnalysis.analysis import dihedrals
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

u = mda.Universe('../../BSA_b-BSA_b/BSA_b-BSA_b.pdb')
BSA_b_BSA_b = u.select_atoms('protein')
BSA_b1 = BSA_b_BSA_b[range(0,9219)]
BSA_b2 = BSA_b_BSA_b[range(9219,18438)]
BSA_b_BSA_b_com = BSA_b_BSA_b.center_of_mass(compound='residues')
BSA_b1_com = BSA_b1.center_of_mass(compound='residues')
BSA_b2_com = BSA_b2.center_of_mass(compound='residues')
n_BSA_b_BSA_b = len(BSA_b_BSA_b_com)
n_BSA_b1 = len(BSA_b1_com)
n_BSA_b2 = len(BSA_b2_com)
print('BSA_b-BSA_b has {} resisudes and BSA_b1 has {} residues and BSA_b2 has {} residues'.format(n_BSA_b_BSA_b, n_BSA_b1, n_BSA_b2))
rama = dihedrals.Ramachandran(BSA_b_BSA_b).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
plt.title('Ramachandran Plot - BSAb-BSAb')
plt.show()

u = mda.Universe('../../BSA_b-BSA_b_pressed/md_resnr.gro')
BSA_b_BSA_b = u.select_atoms('protein')
BSA_b1 = u.select_atoms('resid 1-583')
BSA_b2 = u.select_atoms('resid 584-1166')
BSA_b_BSA_b_com = BSA_b_BSA_b.center_of_mass(compound='residues')
BSA_b1_com = BSA_b1.center_of_mass(compound='residues')
BSA_b2_com = BSA_b2.center_of_mass(compound='residues')
n_BSA_b_BSA_b = len(BSA_b_BSA_b_com)
n_BSA_b1 = len(BSA_b1_com)
n_BSA_b2 = len(BSA_b2_com)
print('BSA_b-BSA_b has {} resisudes and BSA_b1 has {} residues and BSA_b2 has {} residues'.format(n_BSA_b_BSA_b, n_BSA_b1, n_BSA_b2))
rama = dihedrals.Ramachandran(BSA_b_BSA_b).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
plt.title('Ramachandran Plot - BSAb-BSAb (Pressed)')
plt.show()

u = mda.Universe('../../BSA_b-BSA_b-402x_Cellulose6_pressed/md_resnr.gro')
BSA_b_BSA_b = u.select_atoms('protein')
BSA_b1 = u.select_atoms('resid 1-583')
BSA_b2 = u.select_atoms('resid 584-1166')
BSA_b_BSA_b_com = BSA_b_BSA_b.center_of_mass(compound='residues')
BSA_b1_com = BSA_b1.center_of_mass(compound='residues')
BSA_b2_com = BSA_b2.center_of_mass(compound='residues')
n_BSA_b_BSA_b = len(BSA_b_BSA_b_com)
n_BSA_b1 = len(BSA_b1_com)
n_BSA_b2 = len(BSA_b2_com)
print('BSA_b-BSA_b has {} resisudes and BSA_b1 has {} residues and BSA_b2 has {} residues'.format(n_BSA_b_BSA_b, n_BSA_b1, n_BSA_b2))
rama = dihedrals.Ramachandran(BSA_b_BSA_b).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
plt.title('Ramachandran Plot - 60-20 wt% αCell-BSAb (Pressed)')
plt.show()

u = mda.Universe('../../BSA_b-BSA_b-402x_Cellulose6-292x_SRB-186x_STA_pressed/md_resnr.gro')
BSA_b_BSA_b = u.select_atoms('protein')
BSA_b1 = u.select_atoms('resid 1-583')
BSA_b2 = u.select_atoms('resid 584-1166')
BSA_b_BSA_b_com = BSA_b_BSA_b.center_of_mass(compound='residues')
BSA_b1_com = BSA_b1.center_of_mass(compound='residues')
BSA_b2_com = BSA_b2.center_of_mass(compound='residues')
n_BSA_b_BSA_b = len(BSA_b_BSA_b_com)
n_BSA_b1 = len(BSA_b1_com)
n_BSA_b2 = len(BSA_b2_com)
print('BSA_b-BSA_b has {} resisudes and BSA_b1 has {} residues and BSA_b2 has {} residues'.format(n_BSA_b_BSA_b, n_BSA_b1, n_BSA_b2))
rama = dihedrals.Ramachandran(BSA_b_BSA_b).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
plt.title('Ramachandran Plot - 60-20-10-10 wt% αCell-BSAb-PL-FA (Pressed)')
plt.show()
# Out:
# BSA_b-BSA_b has 1166 resisudes and BSA_b1 has 583 residues and BSA_b2 has 583 residues
# (1, 1162, 2)
# BSA_b-BSA_b has 1166 resisudes and BSA_b1 has 583 residues and BSA_b2 has 583 residues
# (1, 1164, 2)
# BSA_b-BSA_b has 1166 resisudes and BSA_b1 has 583 residues and BSA_b2 has 583 residues
# (1, 1164, 2)
# BSA_b-BSA_b has 1166 resisudes and BSA_b1 has 583 residues and BSA_b2 has 583 residues
# (1, 1164, 2)

# %%
import MDAnalysis as mda
from MDAnalysis.analysis import dihedrals
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['font.family'] = 'Arial Narrow'
import numpy as np
# %matplotlib inline

u = mda.Universe('../../BSA/BSA.pdb')
BSA = u.select_atoms('protein')
BSA_com = BSA.center_of_mass(compound='residues')
n_BSA = len(BSA_com)
print('BSA has {} residues'.format(n_BSA))
rama = dihedrals.Ramachandran(BSA).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
#plt.title('BSA (PDB Crystal)', fontsize = 14, fontweight="bold")
plt.savefig("protein_protein_ramachandran_pdb.svg")
plt.show()

u = mda.Universe('../../BSA_b/BSA_b.pdb')
BSA_b = u.select_atoms('protein')
BSA_b_com = BSA_b.center_of_mass(compound='residues')
n_BSA_b = len(BSA_b_com)
print('BSA_b has {} residues'.format(n_BSA_b))
rama = dihedrals.Ramachandran(BSA_b).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
#plt.title('BSAb', fontsize = 14, fontweight="bold")
plt.savefig("protein_protein_ramachandran_bsab.svg")
plt.show()

u = mda.Universe('../../BSA_b-BSA_b/BSA_b-BSA_b.pdb')
BSA_b_BSA_b = u.select_atoms('protein')
BSA_b1 = BSA_b_BSA_b[range(0,9219)]
BSA_b2 = BSA_b_BSA_b[range(9219,18438)]
BSA_b_BSA_b_com = BSA_b_BSA_b.center_of_mass(compound='residues')
BSA_b1_com = BSA_b1.center_of_mass(compound='residues')
BSA_b2_com = BSA_b2.center_of_mass(compound='residues')
n_BSA_b_BSA_b = len(BSA_b_BSA_b_com)
n_BSA_b1 = len(BSA_b1_com)
n_BSA_b2 = len(BSA_b2_com)
print('BSA_b-BSA_b has {} resisudes and BSA_b1 has {} residues and BSA_b2 has {} residues'.format(n_BSA_b_BSA_b, n_BSA_b1, n_BSA_b2))
rama = dihedrals.Ramachandran(BSA_b_BSA_b).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
#plt.title('BSAb-BSAb', fontsize = 14, fontweight="bold")
plt.savefig("protein_protein_ramachandran_bsabbsab.svg")
plt.show()

u = mda.Universe('../../BSA_b-BSA_b_powder/md_resnr.gro')
BSA_b_BSA_b = u.select_atoms('protein')
BSA_b1 = u.select_atoms('resid 1-583')
BSA_b2 = u.select_atoms('resid 584-1166')
BSA_b_BSA_b_com = BSA_b_BSA_b.center_of_mass(compound='residues')
BSA_b1_com = BSA_b1.center_of_mass(compound='residues')
BSA_b2_com = BSA_b2.center_of_mass(compound='residues')
n_BSA_b_BSA_b = len(BSA_b_BSA_b_com)
n_BSA_b1 = len(BSA_b1_com)
n_BSA_b2 = len(BSA_b2_com)
print('BSA_b-BSA_b has {} resisudes and BSA_b1 has {} residues and BSA_b2 has {} residues'.format(n_BSA_b_BSA_b, n_BSA_b1, n_BSA_b2))
rama = dihedrals.Ramachandran(BSA_b_BSA_b).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
#plt.title('BSA (Powder-Sim)', fontsize = 14, fontweight="bold")
plt.savefig("protein_protein_ramachandran_powder.svg")
plt.show()

u = mda.Universe('../../BSA_b-BSA_b_pressed/md_resnr.gro')
BSA_b_BSA_b = u.select_atoms('protein')
BSA_b1 = u.select_atoms('resid 1-583')
BSA_b2 = u.select_atoms('resid 584-1166')
BSA_b_BSA_b_com = BSA_b_BSA_b.center_of_mass(compound='residues')
BSA_b1_com = BSA_b1.center_of_mass(compound='residues')
BSA_b2_com = BSA_b2.center_of_mass(compound='residues')
n_BSA_b_BSA_b = len(BSA_b_BSA_b_com)
n_BSA_b1 = len(BSA_b1_com)
n_BSA_b2 = len(BSA_b2_com)
print('BSA_b-BSA_b has {} resisudes and BSA_b1 has {} residues and BSA_b2 has {} residues'.format(n_BSA_b_BSA_b, n_BSA_b1, n_BSA_b2))
rama = dihedrals.Ramachandran(BSA_b_BSA_b).run()
print(rama.results.angles.shape)
rama.plot(color='red', marker='.', ref=True)
#plt.title('BSA (Press-Sim)', fontsize = 14, fontweight="bold")
plt.savefig("protein_protein_ramachandran_pressed.svg")
plt.show()
# Out:
# BSA has 583 residues
# (1, 581, 2)
# BSA_b has 583 residues
# (1, 581, 2)
# BSA_b-BSA_b has 1166 resisudes and BSA_b1 has 583 residues and BSA_b2 has 583 residues
# (1, 1162, 2)
# BSA_b-BSA_b has 1166 resisudes and BSA_b1 has 583 residues and BSA_b2 has 583 residues
# (1, 1164, 2)
# BSA_b-BSA_b has 1166 resisudes and BSA_b1 has 583 residues and BSA_b2 has 583 residues
# (1, 1164, 2)
